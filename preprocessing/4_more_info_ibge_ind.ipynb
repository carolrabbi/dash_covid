# %% [markdown]
# ### Mais informações sobre cada indicador do IBGE
#
# Os indicadores das pesquisas são hierarquicamente organizados, podendo chegar a 6 níveis (!). Para ler o json e extrair as relações certas entre cada indicador e seu significado, precisamos navegar no json e buscar:
# * posição: nível da hierarquia, ex: 1.1.2.1.2
# * indicador: grão daquela medida, ex: Pré-escola, 6º ano, Privado, Estadual
# * classe: se é numérico, ex: I, N, T
# * unidade: fala o que está sendo medido, ex: "docentes - N"

# %%
import json
import pandas as pd

# %% [markdown]
# ### 0. Constantes

# %%
path_data = 'D:/data_dash_covid/datasets/'

# %% [markdown]
# ### 1. Read data

# %%
with open(path_data + 'raw/ibge_cidades/indicadores-da-pesquisa-10096.json') as json_file:
    mydata = json.load(json_file)

# %% [markdown]
# ### 2. Walk through nested json
#
# Brilliant solution from [here](https://hackersandslackers.com/extract-data-from-complex-json-python/)

# %%
"""Extract nested values from a JSON tree."""


def json_extract(obj, key):
    """Recursively fetch values from nested JSON."""
    arr = []

    def extract(obj, arr, key):
        """Recursively search for values of key in JSON tree."""
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, key)
                elif k == key:
                    arr.append(v)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)
        return arr

    values = extract(obj, arr, key)
    return values

# %% [markdown]
# ### 3. Get additional info
#
# Para cada Pesquisa:
# * posição
# * indicador
# * classe
# * unidade

# %%
list_posicao = json_extract(mydata, 'posicao')
print(len(list_posicao))
# Out:
# 1090

# %%
list_indicador = json_extract(mydata, 'indicador')
print(len(list_indicador))
# Out:
# 1090

# %%
list_ids = json_extract(mydata, 'id')
list_ids = [i for i in list_ids if isinstance(i,int)]
print(len(list_ids))
# Out:
# 1090

# %%
teste_df = list(zip(list_ids,list_posicao,list_indicador))
teste_df
# Out:
# [(84179, '1', 'Total'),
#  (84180, '1.1', 'Situação operacional'),
#  (84181,
#   '1.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (84182, '1.1.1.1', 'Percentual em relação ao número de empresas'),
#  (84183, '1.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (84184, '1.1.1.2.1', 'Impacto negativo'),
#  (84185, '1.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (84186, '1.1.1.2.3', 'Impacto positivo'),
#  (84187, '1.1.1.2.4', 'Não soube responder'),
#  (84188,
#   '1.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (84189, '1.1.1.3.1', 'Impacto negativo'),
#  (84190, '1.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (84191, '1.1.1.3.3', 'Impacto positivo'),
#  (84192, '1.1.1.3.4', 'Não soube responder'),
#  (84193,
#   '1.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (84194, '1.1.1.4.1', 'Impacto negativo'),
#  (84195, '1.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (84196, '1.1.1.4.3', 'Impacto positivo'),
#  (84197, '1.1.1.4.4', 'Não soube responder'),
#  (84198,
#   '1.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (84199, '1.1.1.5.1', 'Impacto negativo'),
#  (84200, '1.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (84201, '1.1.1.5.3', 'Impacto positivo'),
#  (84202, '1.1.1.5.4', 'Não soube responder'),
#  (84203,
#   '1.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (84204, '1.1.1.6.1', 'Impacto negativo'),
#  (84205, '1.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (84206, '1.1.1.6.3', 'Impacto positivo'),
#  (84207, '1.1.1.6.4', 'Não soube responder'),
#  (84208,
#   '1.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84209,
#   '1.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (84210,
#   '1.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (84211, '1.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (84212, '1.1.1.7.3.1', 'Com apoio governamental'),
#  (84213, '1.1.1.7.3.2', 'Sem apoio governamental'),
#  (84214,
#   '1.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (84215, '1.1.1.7.4.1', 'Com apoio governamental'),
#  (84216, '1.1.1.7.4.2', 'Sem apoio governamental'),
#  (84217,
#   '1.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (84218, '1.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (84219,
#   '1.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (84220, '1.1.1.7.8', 'Não adotou nenhuma medida'),
#  (84221, '1.1.1.7.9', 'Outras medidas'),
#  (84222, '1.1.1.7.10', 'Não soube responder'),
#  (84223,
#   '1.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84224, '1.1.1.8.1', 'Sim'),
#  (84225, '1.1.1.8.2', 'Não'),
#  (84226, '1.1.1.9', 'Variação no número de funcionários'),
#  (84227, '1.1.1.9.1', 'Houve redução'),
#  (84228, '1.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (84229, '1.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (84230, '1.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (84231, '1.1.1.9.1.4', 'Não soube responder'),
#  (84232, '1.1.1.9.2', 'Não houve mudança'),
#  (84233, '1.1.1.9.3', 'Houve aumento'),
#  (84234, '1.1.1.9.4', 'Não soube responder'),
#  (84235, '1.1.2', 'Temporariamente fechada'),
#  (84236, '1.1.2.1', 'Percentual em relação ao número de empresas'),
#  (84237, '1.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (84238, '1.1.2.2.1', 'Sim'),
#  (84239, '1.1.2.2.2', 'Não'),
#  (84240, '1.1.2.2.3', 'Não soube responder'),
#  (84241, '1.1.3', 'Fechada em definitivo'),
#  (84242, '1.1.3.1', 'Percentual em relação ao número de empresas'),
#  (84243, '1.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (84244, '1.1.3.2.1', 'Sim'),
#  (84245, '1.1.3.2.2', 'Não'),
#  (84246, '1.1.3.2.3', 'Não soube responder'),
#  (83157, '2', 'Faixas de pessoal ocupado'),
#  (83158, '2.1', 'Até 49 pessoas ocupadas'),
#  (83159, '2.1.1', 'Situação operacional'),
#  (83160,
#   '2.1.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83161, '2.1.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83162, '2.1.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83163, '2.1.1.1.2.1', 'Impacto negativo'),
#  (83164, '2.1.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83165, '2.1.1.1.2.3', 'Impacto positivo'),
#  (83166, '2.1.1.1.2.4', 'Não soube responder'),
#  (83167,
#   '2.1.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83168, '2.1.1.1.3.1', 'Impacto negativo'),
#  (83169, '2.1.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83170, '2.1.1.1.3.3', 'Impacto positivo'),
#  (83171, '2.1.1.1.3.4', 'Não soube responder'),
#  (83172,
#   '2.1.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83173, '2.1.1.1.4.1', 'Impacto negativo'),
#  (83174, '2.1.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83175, '2.1.1.1.4.3', 'Impacto positivo'),
#  (83176, '2.1.1.1.4.4', 'Não soube responder'),
#  (83177,
#   '2.1.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83178, '2.1.1.1.5.1', 'Impacto negativo'),
#  (83179, '2.1.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83180, '2.1.1.1.5.3', 'Impacto positivo'),
#  (83181, '2.1.1.1.5.4', 'Não soube responder'),
#  (83182,
#   '2.1.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83183, '2.1.1.1.6.1', 'Impacto negativo'),
#  (83184, '2.1.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83185, '2.1.1.1.6.3', 'Impacto positivo'),
#  (83186, '2.1.1.1.6.4', 'Não soube responder'),
#  (83187,
#   '2.1.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83188,
#   '2.1.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83189,
#   '2.1.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83190, '2.1.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83191, '2.1.1.1.7.3.1', 'Com apoio governamental'),
#  (83192, '2.1.1.1.7.3.2', 'Sem apoio governamental'),
#  (83193,
#   '2.1.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83194, '2.1.1.1.7.4.1', 'Com apoio governamental'),
#  (83195, '2.1.1.1.7.4.2', 'Sem apoio governamental'),
#  (83196,
#   '2.1.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83197, '2.1.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83198,
#   '2.1.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83199, '2.1.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83200, '2.1.1.1.7.9', 'Outras medidas'),
#  (83201, '2.1.1.1.7.10', 'Não soube responder'),
#  (83202,
#   '2.1.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83203, '2.1.1.1.8.1', 'Sim'),
#  (83204, '2.1.1.1.8.2', 'Não'),
#  (83205, '2.1.1.1.9', 'Variação no número de funcionários'),
#  (83206, '2.1.1.1.9.1', 'Houve redução'),
#  (83207, '2.1.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83208, '2.1.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83209, '2.1.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83210, '2.1.1.1.9.1.4', 'Não soube responder'),
#  (83211, '2.1.1.1.9.2', 'Não houve mudança'),
#  (83212, '2.1.1.1.9.3', 'Houve aumento'),
#  (83213, '2.1.1.1.9.4', 'Não soube responder'),
#  (83214, '2.1.1.2', 'Temporariamente fechada'),
#  (83215, '2.1.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83216, '2.1.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83217, '2.1.1.2.2.1', 'Sim'),
#  (83218, '2.1.1.2.2.2', 'Não'),
#  (83219, '2.1.1.2.2.3', 'Não soube responder'),
#  (83220, '2.1.1.3', 'Fechada em definitivo'),
#  (83221, '2.1.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83222, '2.1.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83223, '2.1.1.3.2.1', 'Sim'),
#  (83224, '2.1.1.3.2.2', 'Não'),
#  (83225, '2.1.1.3.2.3', 'Não soube responder'),
#  (83226, '2.2', '50 a 499 pessoas ocupadas'),
#  (83227, '2.2.1', 'Situação operacional'),
#  (83228,
#   '2.2.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83229, '2.2.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83230, '2.2.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83231, '2.2.1.1.2.1', 'Impacto negativo'),
#  (83232, '2.2.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83233, '2.2.1.1.2.3', 'Impacto positivo'),
#  (83234, '2.2.1.1.2.4', 'Não soube responder'),
#  (83235,
#   '2.2.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83236, '2.2.1.1.3.1', 'Impacto negativo'),
#  (83237, '2.2.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83238, '2.2.1.1.3.3', 'Impacto positivo'),
#  (83239, '2.2.1.1.3.4', 'Não soube responder'),
#  (83240,
#   '2.2.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83241, '2.2.1.1.4.1', 'Impacto negativo'),
#  (83242, '2.2.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83243, '2.2.1.1.4.3', 'Impacto positivo'),
#  (83244, '2.2.1.1.4.4', 'Não soube responder'),
#  (83245,
#   '2.2.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83246, '2.2.1.1.5.1', 'Impacto negativo'),
#  (83247, '2.2.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83248, '2.2.1.1.5.3', 'Impacto positivo'),
#  (83249, '2.2.1.1.5.4', 'Não soube responder'),
#  (83250,
#   '2.2.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83251, '2.2.1.1.6.1', 'Impacto negativo'),
#  (83252, '2.2.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83253, '2.2.1.1.6.3', 'Impacto positivo'),
#  (83254, '2.2.1.1.6.4', 'Não soube responder'),
#  (83255,
#   '2.2.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83256,
#   '2.2.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83257,
#   '2.2.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83258, '2.2.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83259, '2.2.1.1.7.3.1', 'Com apoio governamental'),
#  (83260, '2.2.1.1.7.3.2', 'Sem apoio governamental'),
#  (83261,
#   '2.2.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83262, '2.2.1.1.7.4.1', 'Com apoio governamental'),
#  (83263, '2.2.1.1.7.4.2', 'Sem apoio governamental'),
#  (83264,
#   '2.2.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83265, '2.2.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83266,
#   '2.2.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83267, '2.2.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83268, '2.2.1.1.7.9', 'Outras medidas'),
#  (83269, '2.2.1.1.7.10', 'Não soube responder'),
#  (83270,
#   '2.2.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83271, '2.2.1.1.8.1', 'Sim'),
#  (83272, '2.2.1.1.8.2', 'Não'),
#  (83273, '2.2.1.1.9', 'Variação no número de funcionários'),
#  (83274, '2.2.1.1.9.1', 'Houve redução'),
#  (83275, '2.2.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83276, '2.2.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83277, '2.2.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83278, '2.2.1.1.9.1.4', 'Não soube responder'),
#  (83279, '2.2.1.1.9.2', 'Não houve mudança'),
#  (83280, '2.2.1.1.9.3', 'Houve aumento'),
#  (83281, '2.2.1.1.9.4', 'Não soube responder'),
#  (83282, '2.2.1.2', 'Temporariamente fechada'),
#  (83283, '2.2.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83284, '2.2.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83285, '2.2.1.2.2.1', 'Sim'),
#  (83286, '2.2.1.2.2.2', 'Não'),
#  (83287, '2.2.1.2.2.3', 'Não soube responder'),
#  (83288, '2.2.1.3', 'Fechada em definitivo'),
#  (83289, '2.2.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83290, '2.2.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83291, '2.2.1.3.2.1', 'Sim'),
#  (83292, '2.2.1.3.2.2', 'Não'),
#  (83293, '2.2.1.3.2.3', 'Não soube responder'),
#  (83294, '2.3', '500 ou mais pessoas ocupadas'),
#  (83295, '2.3.1', 'Situação operacional'),
#  (83296,
#   '2.3.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83297, '2.3.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83298, '2.3.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83299, '2.3.1.1.2.1', 'Impacto negativo'),
#  (83300, '2.3.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83301, '2.3.1.1.2.3', 'Impacto positivo'),
#  (83302, '2.3.1.1.2.4', 'Não soube responder'),
#  (83303,
#   '2.3.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83304, '2.3.1.1.3.1', 'Impacto negativo'),
#  (83305, '2.3.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83306, '2.3.1.1.3.3', 'Impacto positivo'),
#  (83307, '2.3.1.1.3.4', 'Não soube responder'),
#  (83308,
#   '2.3.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83309, '2.3.1.1.4.1', 'Impacto negativo'),
#  (83310, '2.3.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83311, '2.3.1.1.4.3', 'Impacto positivo'),
#  (83312, '2.3.1.1.4.4', 'Não soube responder'),
#  (83313,
#   '2.3.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83314, '2.3.1.1.5.1', 'Impacto negativo'),
#  (83315, '2.3.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83316, '2.3.1.1.5.3', 'Impacto positivo'),
#  (83317, '2.3.1.1.5.4', 'Não soube responder'),
#  (83318,
#   '2.3.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83319, '2.3.1.1.6.1', 'Impacto negativo'),
#  (83320, '2.3.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83321, '2.3.1.1.6.3', 'Impacto positivo'),
#  (83322, '2.3.1.1.6.4', 'Não soube responder'),
#  (83323,
#   '2.3.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83324,
#   '2.3.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83325,
#   '2.3.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83326, '2.3.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83327, '2.3.1.1.7.3.1', 'Com apoio governamental'),
#  (83328, '2.3.1.1.7.3.2', 'Sem apoio governamental'),
#  (83329,
#   '2.3.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83330, '2.3.1.1.7.4.1', 'Com apoio governamental'),
#  (83331, '2.3.1.1.7.4.2', 'Sem apoio governamental'),
#  (83332,
#   '2.3.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83333, '2.3.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83334,
#   '2.3.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83335, '2.3.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83336, '2.3.1.1.7.9', 'Outras medidas'),
#  (83337, '2.3.1.1.7.10', 'Não soube responder'),
#  (83338,
#   '2.3.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83339, '2.3.1.1.8.1', 'Sim'),
#  (83340, '2.3.1.1.8.2', 'Não'),
#  (83341, '2.3.1.1.9', 'Variação no número de funcionários'),
#  (83342, '2.3.1.1.9.1', 'Houve redução'),
#  (83343, '2.3.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83344, '2.3.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83345, '2.3.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83346, '2.3.1.1.9.1.4', 'Não soube responder'),
#  (83347, '2.3.1.1.9.2', 'Não houve mudança'),
#  (83348, '2.3.1.1.9.3', 'Houve aumento'),
#  (83349, '2.3.1.1.9.4', 'Não soube responder'),
#  (83350, '2.3.1.2', 'Temporariamente fechada'),
#  (83351, '2.3.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83352, '2.3.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83353, '2.3.1.2.2.1', 'Sim'),
#  (83354, '2.3.1.2.2.2', 'Não'),
#  (83355, '2.3.1.2.2.3', 'Não soube responder'),
#  (83356, '2.3.1.3', 'Fechada em definitivo'),
#  (83357, '2.3.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83358, '2.3.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83359, '2.3.1.3.2.1', 'Sim'),
#  (83360, '2.3.1.3.2.2', 'Não'),
#  (83361, '2.3.1.3.2.3', 'Não soube responder'),
#  (83362, '3', 'Atividade'),
#  (83363, '3.1', 'Indústria'),
#  (83364, '3.1.1', 'Situação operacional'),
#  (83365,
#   '3.1.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83366, '3.1.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83367, '3.1.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83368, '3.1.1.1.2.1', 'Impacto negativo'),
#  (83369, '3.1.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83370, '3.1.1.1.2.3', 'Impacto positivo'),
#  (83371, '3.1.1.1.2.4', 'Não soube responder'),
#  (83372,
#   '3.1.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83373, '3.1.1.1.3.1', 'Impacto negativo'),
#  (83374, '3.1.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83375, '3.1.1.1.3.3', 'Impacto positivo'),
#  (83376, '3.1.1.1.3.4', 'Não soube responder'),
#  (83377,
#   '3.1.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83378, '3.1.1.1.4.1', 'Impacto negativo'),
#  (83379, '3.1.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83380, '3.1.1.1.4.3', 'Impacto positivo'),
#  (83381, '3.1.1.1.4.4', 'Não soube responder'),
#  (83382,
#   '3.1.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83383, '3.1.1.1.5.1', 'Impacto negativo'),
#  (83384, '3.1.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83385, '3.1.1.1.5.3', 'Impacto positivo'),
#  (83386, '3.1.1.1.5.4', 'Não soube responder'),
#  (83387,
#   '3.1.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83388, '3.1.1.1.6.1', 'Impacto negativo'),
#  (83389, '3.1.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83390, '3.1.1.1.6.3', 'Impacto positivo'),
#  (83391, '3.1.1.1.6.4', 'Não soube responder'),
#  (83392,
#   '3.1.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83393,
#   '3.1.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83394,
#   '3.1.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83395, '3.1.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83396, '3.1.1.1.7.3.1', 'Com apoio governamental'),
#  (83397, '3.1.1.1.7.3.2', 'Sem apoio governamental'),
#  (83398,
#   '3.1.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83399, '3.1.1.1.7.4.1', 'Com apoio governamental'),
#  (83400, '3.1.1.1.7.4.2', 'Sem apoio governamental'),
#  (83401,
#   '3.1.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83402, '3.1.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83403,
#   '3.1.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83404, '3.1.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83405, '3.1.1.1.7.9', 'Outras medidas'),
#  (83406, '3.1.1.1.7.10', 'Não soube responder'),
#  (83407,
#   '3.1.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83408, '3.1.1.1.8.1', 'Sim'),
#  (83409, '3.1.1.1.8.2', 'Não'),
#  (83410, '3.1.1.1.9', 'Variação no número de funcionários'),
#  (83411, '3.1.1.1.9.1', 'Houve redução'),
#  (83412, '3.1.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83413, '3.1.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83414, '3.1.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83415, '3.1.1.1.9.1.4', 'Não soube responder'),
#  (83416, '3.1.1.1.9.2', 'Não houve mudança'),
#  (83417, '3.1.1.1.9.3', 'Houve aumento'),
#  (83418, '3.1.1.1.9.4', 'Não soube responder'),
#  (83419, '3.1.1.2', 'Temporariamente fechada'),
#  (83420, '3.1.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83421, '3.1.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83422, '3.1.1.2.2.1', 'Sim'),
#  (83423, '3.1.1.2.2.2', 'Não'),
#  (83424, '3.1.1.2.2.3', 'Não soube responder'),
#  (83425, '3.1.1.3', 'Fechada em definitivo'),
#  (83426, '3.1.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83427, '3.1.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83428, '3.1.1.3.2.1', 'Sim'),
#  (83429, '3.1.1.3.2.2', 'Não'),
#  (83430, '3.1.1.3.2.3', 'Não soube responder'),
#  (83431, '3.2', 'Construção'),
#  (83432, '3.2.1', 'Situação operacional'),
#  (83433,
#   '3.2.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83434, '3.2.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83435, '3.2.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83436, '3.2.1.1.2.1', 'Impacto negativo'),
#  (83437, '3.2.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83438, '3.2.1.1.2.3', 'Impacto positivo'),
#  (83439, '3.2.1.1.2.4', 'Não soube responder'),
#  (83440,
#   '3.2.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83441, '3.2.1.1.3.1', 'Impacto negativo'),
#  (83442, '3.2.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83443, '3.2.1.1.3.3', 'Impacto positivo'),
#  (83444, '3.2.1.1.3.4', 'Não soube responder'),
#  (83445,
#   '3.2.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83446, '3.2.1.1.4.1', 'Impacto negativo'),
#  (83447, '3.2.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83448, '3.2.1.1.4.3', 'Impacto positivo'),
#  (83449, '3.2.1.1.4.4', 'Não soube responder'),
#  (83450,
#   '3.2.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83451, '3.2.1.1.5.1', 'Impacto negativo'),
#  (83452, '3.2.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83453, '3.2.1.1.5.3', 'Impacto positivo'),
#  (83454, '3.2.1.1.5.4', 'Não soube responder'),
#  (83455,
#   '3.2.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83456, '3.2.1.1.6.1', 'Impacto negativo'),
#  (83457, '3.2.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83458, '3.2.1.1.6.3', 'Impacto positivo'),
#  (83459, '3.2.1.1.6.4', 'Não soube responder'),
#  (83460,
#   '3.2.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83461,
#   '3.2.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83462,
#   '3.2.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83463, '3.2.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83464, '3.2.1.1.7.3.1', 'Com apoio governamental'),
#  (83465, '3.2.1.1.7.3.2', 'Sem apoio governamental'),
#  (83466,
#   '3.2.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83467, '3.2.1.1.7.4.1', 'Com apoio governamental'),
#  (83468, '3.2.1.1.7.4.2', 'Sem apoio governamental'),
#  (83469,
#   '3.2.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83470, '3.2.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83471,
#   '3.2.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83472, '3.2.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83473, '3.2.1.1.7.9', 'Outras medidas'),
#  (83474, '3.2.1.1.7.10', 'Não soube responder'),
#  (83475,
#   '3.2.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83476, '3.2.1.1.8.1', 'Sim'),
#  (83477, '3.2.1.1.8.2', 'Não'),
#  (83478, '3.2.1.1.9', 'Variação no número de funcionários'),
#  (83479, '3.2.1.1.9.1', 'Houve redução'),
#  (83480, '3.2.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83481, '3.2.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83482, '3.2.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83483, '3.2.1.1.9.1.4', 'Não soube responder'),
#  (83484, '3.2.1.1.9.2', 'Não houve mudança'),
#  (83485, '3.2.1.1.9.3', 'Houve aumento'),
#  (83486, '3.2.1.1.9.4', 'Não soube responder'),
#  (83487, '3.2.1.2', 'Temporariamente fechada'),
#  (83488, '3.2.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83489, '3.2.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83490, '3.2.1.2.2.1', 'Sim'),
#  (83491, '3.2.1.2.2.2', 'Não'),
#  (83492, '3.2.1.2.2.3', 'Não soube responder'),
#  (83493, '3.2.1.3', 'Fechada em definitivo'),
#  (83494, '3.2.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83495, '3.2.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83496, '3.2.1.3.2.1', 'Sim'),
#  (83497, '3.2.1.3.2.2', 'Não'),
#  (83498, '3.2.1.3.2.3', 'Não soube responder'),
#  (83499, '3.3', 'Comércio'),
#  (83500, '3.3.1', 'Situação operacional'),
#  (83501,
#   '3.3.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83502, '3.3.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83503, '3.3.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83504, '3.3.1.1.2.1', 'Impacto negativo'),
#  (83505, '3.3.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83506, '3.3.1.1.2.3', 'Impacto positivo'),
#  (83507, '3.3.1.1.2.4', 'Não soube responder'),
#  (83508,
#   '3.3.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83509, '3.3.1.1.3.1', 'Impacto negativo'),
#  (83510, '3.3.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83511, '3.3.1.1.3.3', 'Impacto positivo'),
#  (83512, '3.3.1.1.3.4', 'Não soube responder'),
#  (83513,
#   '3.3.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83514, '3.3.1.1.4.1', 'Impacto negativo'),
#  (83515, '3.3.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83516, '3.3.1.1.4.3', 'Impacto positivo'),
#  (83517, '3.3.1.1.4.4', 'Não soube responder'),
#  (83518,
#   '3.3.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83519, '3.3.1.1.5.1', 'Impacto negativo'),
#  (83520, '3.3.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83521, '3.3.1.1.5.3', 'Impacto positivo'),
#  (83522, '3.3.1.1.5.4', 'Não soube responder'),
#  (83523,
#   '3.3.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83524, '3.3.1.1.6.1', 'Impacto negativo'),
#  (83525, '3.3.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83526, '3.3.1.1.6.3', 'Impacto positivo'),
#  (83527, '3.3.1.1.6.4', 'Não soube responder'),
#  (83528,
#   '3.3.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83529,
#   '3.3.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83530,
#   '3.3.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83531, '3.3.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83532, '3.3.1.1.7.3.1', 'Com apoio governamental'),
#  (83533, '3.3.1.1.7.3.2', 'Sem apoio governamental'),
#  (83534,
#   '3.3.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83535, '3.3.1.1.7.4.1', 'Com apoio governamental'),
#  (83536, '3.3.1.1.7.4.2', 'Sem apoio governamental'),
#  (83537,
#   '3.3.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83538, '3.3.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83539,
#   '3.3.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83540, '3.3.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83541, '3.3.1.1.7.9', 'Outras medidas'),
#  (83542, '3.3.1.1.7.10', 'Não soube responder'),
#  (83543,
#   '3.3.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83544, '3.3.1.1.8.1', 'Sim'),
#  (83545, '3.3.1.1.8.2', 'Não'),
#  (83546, '3.3.1.1.9', 'Variação no número de funcionários'),
#  (83547, '3.3.1.1.9.1', 'Houve redução'),
#  (83548, '3.3.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83549, '3.3.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83550, '3.3.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83551, '3.3.1.1.9.1.4', 'Não soube responder'),
#  (83552, '3.3.1.1.9.2', 'Não houve mudança'),
#  (83553, '3.3.1.1.9.3', 'Houve aumento'),
#  (83554, '3.3.1.1.9.4', 'Não soube responder'),
#  (83555, '3.3.1.2', 'Temporariamente fechada'),
#  (83556, '3.3.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83557, '3.3.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83558, '3.3.1.2.2.1', 'Sim'),
#  (83559, '3.3.1.2.2.2', 'Não'),
#  (83560, '3.3.1.2.2.3', 'Não soube responder'),
#  (83561, '3.3.1.3', 'Fechada em definitivo'),
#  (83562, '3.3.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83563, '3.3.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83564, '3.3.1.3.2.1', 'Sim'),
#  (83565, '3.3.1.3.2.2', 'Não'),
#  (83566, '3.3.1.3.2.3', 'Não soube responder'),
#  (83567, '3.3.2', 'Varejista'),
#  (83568, '3.3.2.1', 'Situação operacional'),
#  (83569,
#   '3.3.2.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83570, '3.3.2.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83571, '3.3.2.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83572, '3.3.2.1.1.2.1', 'Impacto negativo'),
#  (83573, '3.3.2.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83574, '3.3.2.1.1.2.3', 'Impacto positivo'),
#  (83575, '3.3.2.1.1.2.4', 'Não soube responder'),
#  (83576,
#   '3.3.2.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83577, '3.3.2.1.1.3.1', 'Impacto negativo'),
#  (83578, '3.3.2.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83579, '3.3.2.1.1.3.3', 'Impacto positivo'),
#  (83580, '3.3.2.1.1.3.4', 'Não soube responder'),
#  (83581,
#   '3.3.2.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83582, '3.3.2.1.1.4.1', 'Impacto negativo'),
#  (83583, '3.3.2.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83584, '3.3.2.1.1.4.3', 'Impacto positivo'),
#  (83585, '3.3.2.1.1.4.4', 'Não soube responder'),
#  (83586,
#   '3.3.2.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83587, '3.3.2.1.1.5.1', 'Impacto negativo'),
#  (83588, '3.3.2.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83589, '3.3.2.1.1.5.3', 'Impacto positivo'),
#  (83590, '3.3.2.1.1.5.4', 'Não soube responder'),
#  (83591,
#   '3.3.2.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83592, '3.3.2.1.1.6.1', 'Impacto negativo'),
#  (83593, '3.3.2.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83594, '3.3.2.1.1.6.3', 'Impacto positivo'),
#  (83595, '3.3.2.1.1.6.4', 'Não soube responder'),
#  (83596,
#   '3.3.2.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83597,
#   '3.3.2.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83598,
#   '3.3.2.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83599, '3.3.2.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83600, '3.3.2.1.1.7.3.1', 'Com apoio governamental'),
#  (83601, '3.3.2.1.1.7.3.2', 'Sem apoio governamental'),
#  (83602,
#   '3.3.2.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83603, '3.3.2.1.1.7.4.1', 'Com apoio governamental'),
#  (83604, '3.3.2.1.1.7.4.2', 'Sem apoio governamental'),
#  (83605,
#   '3.3.2.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83606, '3.3.2.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83607,
#   '3.3.2.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83608, '3.3.2.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83609, '3.3.2.1.1.7.9', 'Outras medidas'),
#  (83610, '3.3.2.1.1.7.10', 'Não soube responder'),
#  (83611,
#   '3.3.2.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83612, '3.3.2.1.1.8.1', 'Sim'),
#  (83613, '3.3.2.1.1.8.2', 'Não'),
#  (83614, '3.3.2.1.1.9', 'Variação no número de funcionários'),
#  (83615, '3.3.2.1.1.9.1', 'Houve redução'),
#  (83616, '3.3.2.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83617, '3.3.2.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83618, '3.3.2.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83619, '3.3.2.1.1.9.1.4', 'Não soube responder'),
#  (83620, '3.3.2.1.1.9.2', 'Não houve mudança'),
#  (83621, '3.3.2.1.1.9.3', 'Houve aumento'),
#  (83622, '3.3.2.1.1.9.4', 'Não soube responder'),
#  (83623, '3.3.2.1.2', 'Temporariamente fechada'),
#  (83624, '3.3.2.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83625, '3.3.2.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83626, '3.3.2.1.2.2.1', 'Sim'),
#  (83627, '3.3.2.1.2.2.2', 'Não'),
#  (83628, '3.3.2.1.2.2.3', 'Não soube responder'),
#  (83629, '3.3.2.1.3', 'Fechada em definitivo'),
#  (83630, '3.3.2.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83631, '3.3.2.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83632, '3.3.2.1.3.2.1', 'Sim'),
#  (83633, '3.3.2.1.3.2.2', 'Não'),
#  (83634, '3.3.2.1.3.2.3', 'Não soube responder'),
#  (83635, '3.3.3', 'Atacadista'),
#  (83636, '3.3.3.1', 'Situação operacional'),
#  (83637,
#   '3.3.3.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83638, '3.3.3.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83639, '3.3.3.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83640, '3.3.3.1.1.2.1', 'Impacto negativo'),
#  (83641, '3.3.3.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83642, '3.3.3.1.1.2.3', 'Impacto positivo'),
#  (83643, '3.3.3.1.1.2.4', 'Não soube responder'),
#  (83644,
#   '3.3.3.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83645, '3.3.3.1.1.3.1', 'Impacto negativo'),
#  (83646, '3.3.3.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83647, '3.3.3.1.1.3.3', 'Impacto positivo'),
#  (83648, '3.3.3.1.1.3.4', 'Não soube responder'),
#  (83649,
#   '3.3.3.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83650, '3.3.3.1.1.4.1', 'Impacto negativo'),
#  (83651, '3.3.3.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83652, '3.3.3.1.1.4.3', 'Impacto positivo'),
#  (83653, '3.3.3.1.1.4.4', 'Não soube responder'),
#  (83654,
#   '3.3.3.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83655, '3.3.3.1.1.5.1', 'Impacto negativo'),
#  (83656, '3.3.3.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83657, '3.3.3.1.1.5.3', 'Impacto positivo'),
#  (83658, '3.3.3.1.1.5.4', 'Não soube responder'),
#  (83659,
#   '3.3.3.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83660, '3.3.3.1.1.6.1', 'Impacto negativo'),
#  (83661, '3.3.3.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83662, '3.3.3.1.1.6.3', 'Impacto positivo'),
#  (83663, '3.3.3.1.1.6.4', 'Não soube responder'),
#  (83664,
#   '3.3.3.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83665,
#   '3.3.3.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83666,
#   '3.3.3.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83667, '3.3.3.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83668, '3.3.3.1.1.7.3.1', 'Com apoio governamental'),
#  (83669, '3.3.3.1.1.7.3.2', 'Sem apoio governamental'),
#  (83670,
#   '3.3.3.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83671, '3.3.3.1.1.7.4.1', 'Com apoio governamental'),
#  (83672, '3.3.3.1.1.7.4.2', 'Sem apoio governamental'),
#  (83673,
#   '3.3.3.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83674, '3.3.3.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83675,
#   '3.3.3.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83676, '3.3.3.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83677, '3.3.3.1.1.7.9', 'Outras medidas'),
#  (83678, '3.3.3.1.1.7.10', 'Não soube responder'),
#  (83679,
#   '3.3.3.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83680, '3.3.3.1.1.8.1', 'Sim'),
#  (83681, '3.3.3.1.1.8.2', 'Não'),
#  (83682, '3.3.3.1.1.9', 'Variação no número de funcionários'),
#  (83683, '3.3.3.1.1.9.1', 'Houve redução'),
#  (83684, '3.3.3.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83685, '3.3.3.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83686, '3.3.3.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83687, '3.3.3.1.1.9.1.4', 'Não soube responder'),
#  (83688, '3.3.3.1.1.9.2', 'Não houve mudança'),
#  (83689, '3.3.3.1.1.9.3', 'Houve aumento'),
#  (83690, '3.3.3.1.1.9.4', 'Não soube responder'),
#  (83691, '3.3.3.1.2', 'Temporariamente fechada'),
#  (83692, '3.3.3.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83693, '3.3.3.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83694, '3.3.3.1.2.2.1', 'Sim'),
#  (83695, '3.3.3.1.2.2.2', 'Não'),
#  (83696, '3.3.3.1.2.2.3', 'Não soube responder'),
#  (83697, '3.3.3.1.3', 'Fechada em definitivo'),
#  (83698, '3.3.3.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83699, '3.3.3.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83700, '3.3.3.1.3.2.1', 'Sim'),
#  (83701, '3.3.3.1.3.2.2', 'Não'),
#  (83702, '3.3.3.1.3.2.3', 'Não soube responder'),
#  (83703, '3.3.4', 'Comércio de veículos, peças e motocicletas'),
#  (83704, '3.3.4.1', 'Situação operacional'),
#  (83705,
#   '3.3.4.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83706, '3.3.4.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83707, '3.3.4.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83708, '3.3.4.1.1.2.1', 'Impacto negativo'),
#  (83709, '3.3.4.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83710, '3.3.4.1.1.2.3', 'Impacto positivo'),
#  (83711, '3.3.4.1.1.2.4', 'Não soube responder'),
#  (83712,
#   '3.3.4.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83713, '3.3.4.1.1.3.1', 'Impacto negativo'),
#  (83714, '3.3.4.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83715, '3.3.4.1.1.3.3', 'Impacto positivo'),
#  (83716, '3.3.4.1.1.3.4', 'Não soube responder'),
#  (83717,
#   '3.3.4.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83718, '3.3.4.1.1.4.1', 'Impacto negativo'),
#  (83719, '3.3.4.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83720, '3.3.4.1.1.4.3', 'Impacto positivo'),
#  (83721, '3.3.4.1.1.4.4', 'Não soube responder'),
#  (83722,
#   '3.3.4.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83723, '3.3.4.1.1.5.1', 'Impacto negativo'),
#  (83724, '3.3.4.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83725, '3.3.4.1.1.5.3', 'Impacto positivo'),
#  (83726, '3.3.4.1.1.5.4', 'Não soube responder'),
#  (83727,
#   '3.3.4.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83728, '3.3.4.1.1.6.1', 'Impacto negativo'),
#  (83729, '3.3.4.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83730, '3.3.4.1.1.6.3', 'Impacto positivo'),
#  (83731, '3.3.4.1.1.6.4', 'Não soube responder'),
#  (83732,
#   '3.3.4.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83733,
#   '3.3.4.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83734,
#   '3.3.4.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83735, '3.3.4.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83736, '3.3.4.1.1.7.3.1', 'Com apoio governamental'),
#  (83737, '3.3.4.1.1.7.3.2', 'Sem apoio governamental'),
#  (83738,
#   '3.3.4.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83739, '3.3.4.1.1.7.4.1', 'Com apoio governamental'),
#  (83740, '3.3.4.1.1.7.4.2', 'Sem apoio governamental'),
#  (83741,
#   '3.3.4.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83742, '3.3.4.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83743,
#   '3.3.4.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83744, '3.3.4.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83745, '3.3.4.1.1.7.9', 'Outras medidas'),
#  (83746, '3.3.4.1.1.7.10', 'Não soube responder'),
#  (83747,
#   '3.3.4.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83748, '3.3.4.1.1.8.1', 'Sim'),
#  (83749, '3.3.4.1.1.8.2', 'Não'),
#  (83750, '3.3.4.1.1.9', 'Variação no número de funcionários'),
#  (83751, '3.3.4.1.1.9.1', 'Houve redução'),
#  (83752, '3.3.4.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83753, '3.3.4.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83754, '3.3.4.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83755, '3.3.4.1.1.9.1.4', 'Não soube responder'),
#  (83756, '3.3.4.1.1.9.2', 'Não houve mudança'),
#  (83757, '3.3.4.1.1.9.3', 'Houve aumento'),
#  (83758, '3.3.4.1.1.9.4', 'Não soube responder'),
#  (83759, '3.3.4.1.2', 'Temporariamente fechada'),
#  (83760, '3.3.4.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83761, '3.3.4.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83762, '3.3.4.1.2.2.1', 'Sim'),
#  (83763, '3.3.4.1.2.2.2', 'Não'),
#  (83764, '3.3.4.1.2.2.3', 'Não soube responder'),
#  (83765, '3.3.4.1.3', 'Fechada em definitivo'),
#  (83766, '3.3.4.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83767, '3.3.4.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83768, '3.3.4.1.3.2.1', 'Sim'),
#  (83769, '3.3.4.1.3.2.2', 'Não'),
#  (83770, '3.3.4.1.3.2.3', 'Não soube responder'),
#  (83771, '3.4', 'Serviços'),
#  (83772, '3.4.1', 'Situação operacional'),
#  (83773,
#   '3.4.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83774, '3.4.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83775, '3.4.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83776, '3.4.1.1.2.1', 'Impacto negativo'),
#  (83777, '3.4.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83778, '3.4.1.1.2.3', 'Impacto positivo'),
#  (83779, '3.4.1.1.2.4', 'Não soube responder'),
#  (83780,
#   '3.4.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83781, '3.4.1.1.3.1', 'Impacto negativo'),
#  (83782, '3.4.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83783, '3.4.1.1.3.3', 'Impacto positivo'),
#  (83784, '3.4.1.1.3.4', 'Não soube responder'),
#  (83785,
#   '3.4.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83786, '3.4.1.1.4.1', 'Impacto negativo'),
#  (83787, '3.4.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83788, '3.4.1.1.4.3', 'Impacto positivo'),
#  (83789, '3.4.1.1.4.4', 'Não soube responder'),
#  (83790,
#   '3.4.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83791, '3.4.1.1.5.1', 'Impacto negativo'),
#  (83792, '3.4.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83793, '3.4.1.1.5.3', 'Impacto positivo'),
#  (83794, '3.4.1.1.5.4', 'Não soube responder'),
#  (83795,
#   '3.4.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83796, '3.4.1.1.6.1', 'Impacto negativo'),
#  (83797, '3.4.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83798, '3.4.1.1.6.3', 'Impacto positivo'),
#  (83799, '3.4.1.1.6.4', 'Não soube responder'),
#  (83800,
#   '3.4.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83801,
#   '3.4.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83802,
#   '3.4.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83803, '3.4.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83804, '3.4.1.1.7.3.1', 'Com apoio governamental'),
#  (83805, '3.4.1.1.7.3.2', 'Sem apoio governamental'),
#  (83806,
#   '3.4.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83807, '3.4.1.1.7.4.1', 'Com apoio governamental'),
#  (83808, '3.4.1.1.7.4.2', 'Sem apoio governamental'),
#  (83809,
#   '3.4.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83810, '3.4.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83811,
#   '3.4.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83812, '3.4.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83813, '3.4.1.1.7.9', 'Outras medidas'),
#  (83814, '3.4.1.1.7.10', 'Não soube responder'),
#  (83815,
#   '3.4.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83816, '3.4.1.1.8.1', 'Sim'),
#  (83817, '3.4.1.1.8.2', 'Não'),
#  (83818, '3.4.1.1.9', 'Variação no número de funcionários'),
#  (83819, '3.4.1.1.9.1', 'Houve redução'),
#  (83820, '3.4.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83821, '3.4.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83822, '3.4.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83823, '3.4.1.1.9.1.4', 'Não soube responder'),
#  (83824, '3.4.1.1.9.2', 'Não houve mudança'),
#  (83825, '3.4.1.1.9.3', 'Houve aumento'),
#  (83826, '3.4.1.1.9.4', 'Não soube responder'),
#  (83827, '3.4.1.2', 'Temporariamente fechada'),
#  (83828, '3.4.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83829, '3.4.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83830, '3.4.1.2.2.1', 'Sim'),
#  (83831, '3.4.1.2.2.2', 'Não'),
#  (83832, '3.4.1.2.2.3', 'Não soube responder'),
#  (83833, '3.4.1.3', 'Fechada em definitivo'),
#  (83834, '3.4.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83835, '3.4.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83836, '3.4.1.3.2.1', 'Sim'),
#  (83837, '3.4.1.3.2.2', 'Não'),
#  (83838, '3.4.1.3.2.3', 'Não soube responder'),
#  (83839, '3.4.2', 'Serviços prestados às famílias'),
#  (83840, '3.4.2.1', 'Situação operacional'),
#  (83841,
#   '3.4.2.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83842, '3.4.2.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83843, '3.4.2.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83844, '3.4.2.1.1.2.1', 'Impacto negativo'),
#  (83845, '3.4.2.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83846, '3.4.2.1.1.2.3', 'Impacto positivo'),
#  (83847, '3.4.2.1.1.2.4', 'Não soube responder'),
#  (83848,
#   '3.4.2.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83849, '3.4.2.1.1.3.1', 'Impacto negativo'),
#  (83850, '3.4.2.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83851, '3.4.2.1.1.3.3', 'Impacto positivo'),
#  (83852, '3.4.2.1.1.3.4', 'Não soube responder'),
#  (83853,
#   '3.4.2.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83854, '3.4.2.1.1.4.1', 'Impacto negativo'),
#  (83855, '3.4.2.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83856, '3.4.2.1.1.4.3', 'Impacto positivo'),
#  (83857, '3.4.2.1.1.4.4', 'Não soube responder'),
#  (83858,
#   '3.4.2.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83859, '3.4.2.1.1.5.1', 'Impacto negativo'),
#  (83860, '3.4.2.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83861, '3.4.2.1.1.5.3', 'Impacto positivo'),
#  (83862, '3.4.2.1.1.5.4', 'Não soube responder'),
#  (83863,
#   '3.4.2.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83864, '3.4.2.1.1.6.1', 'Impacto negativo'),
#  (83865, '3.4.2.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83866, '3.4.2.1.1.6.3', 'Impacto positivo'),
#  (83867, '3.4.2.1.1.6.4', 'Não soube responder'),
#  (83868,
#   '3.4.2.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83869,
#   '3.4.2.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83870,
#   '3.4.2.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83871, '3.4.2.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83872, '3.4.2.1.1.7.3.1', 'Com apoio governamental'),
#  (83873, '3.4.2.1.1.7.3.2', 'Sem apoio governamental'),
#  (83874,
#   '3.4.2.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83875, '3.4.2.1.1.7.4.1', 'Com apoio governamental'),
#  (83876, '3.4.2.1.1.7.4.2', 'Sem apoio governamental'),
#  (83877,
#   '3.4.2.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83878, '3.4.2.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83879,
#   '3.4.2.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83880, '3.4.2.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83881, '3.4.2.1.1.7.9', 'Outras medidas'),
#  (83882, '3.4.2.1.1.7.10', 'Não soube responder'),
#  (83883,
#   '3.4.2.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83884, '3.4.2.1.1.8.1', 'Sim'),
#  (83885, '3.4.2.1.1.8.2', 'Não'),
#  (83886, '3.4.2.1.1.9', 'Variação no número de funcionários'),
#  (83887, '3.4.2.1.1.9.1', 'Houve redução'),
#  (83888, '3.4.2.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83889, '3.4.2.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83890, '3.4.2.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83891, '3.4.2.1.1.9.1.4', 'Não soube responder'),
#  (83892, '3.4.2.1.1.9.2', 'Não houve mudança'),
#  (83893, '3.4.2.1.1.9.3', 'Houve aumento'),
#  (83894, '3.4.2.1.1.9.4', 'Não soube responder'),
#  (83895, '3.4.2.1.2', 'Temporariamente fechada'),
#  (83896, '3.4.2.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83897, '3.4.2.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83898, '3.4.2.1.2.2.1', 'Sim'),
#  (83899, '3.4.2.1.2.2.2', 'Não'),
#  (83900, '3.4.2.1.2.2.3', 'Não soube responder'),
#  (83901, '3.4.2.1.3', 'Fechada em definitivo'),
#  (83902, '3.4.2.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83903, '3.4.2.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83904, '3.4.2.1.3.2.1', 'Sim'),
#  (83905, '3.4.2.1.3.2.2', 'Não'),
#  (83906, '3.4.2.1.3.2.3', 'Não soube responder'),
#  (83907, '3.4.3', 'Informação e comunicação'),
#  (83908, '3.4.3.1', 'Situação operacional'),
#  (83909,
#   '3.4.3.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83910, '3.4.3.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83911, '3.4.3.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83912, '3.4.3.1.1.2.1', 'Impacto negativo'),
#  (83913, '3.4.3.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83914, '3.4.3.1.1.2.3', 'Impacto positivo'),
#  (83915, '3.4.3.1.1.2.4', 'Não soube responder'),
#  (83916,
#   '3.4.3.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83917, '3.4.3.1.1.3.1', 'Impacto negativo'),
#  (83918, '3.4.3.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83919, '3.4.3.1.1.3.3', 'Impacto positivo'),
#  (83920, '3.4.3.1.1.3.4', 'Não soube responder'),
#  (83921,
#   '3.4.3.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83922, '3.4.3.1.1.4.1', 'Impacto negativo'),
#  (83923, '3.4.3.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83924, '3.4.3.1.1.4.3', 'Impacto positivo'),
#  (83925, '3.4.3.1.1.4.4', 'Não soube responder'),
#  (83926,
#   '3.4.3.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83927, '3.4.3.1.1.5.1', 'Impacto negativo'),
#  (83928, '3.4.3.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83929, '3.4.3.1.1.5.3', 'Impacto positivo'),
#  (83930, '3.4.3.1.1.5.4', 'Não soube responder'),
#  (83931,
#   '3.4.3.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (83932, '3.4.3.1.1.6.1', 'Impacto negativo'),
#  (83933, '3.4.3.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (83934, '3.4.3.1.1.6.3', 'Impacto positivo'),
#  (83935, '3.4.3.1.1.6.4', 'Não soube responder'),
#  (83936,
#   '3.4.3.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83937,
#   '3.4.3.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (83938,
#   '3.4.3.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (83939, '3.4.3.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (83940, '3.4.3.1.1.7.3.1', 'Com apoio governamental'),
#  (83941, '3.4.3.1.1.7.3.2', 'Sem apoio governamental'),
#  (83942,
#   '3.4.3.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (83943, '3.4.3.1.1.7.4.1', 'Com apoio governamental'),
#  (83944, '3.4.3.1.1.7.4.2', 'Sem apoio governamental'),
#  (83945,
#   '3.4.3.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (83946, '3.4.3.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (83947,
#   '3.4.3.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (83948, '3.4.3.1.1.7.8', 'Não adotou nenhuma medida'),
#  (83949, '3.4.3.1.1.7.9', 'Outras medidas'),
#  (83950, '3.4.3.1.1.7.10', 'Não soube responder'),
#  (83951,
#   '3.4.3.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (83952, '3.4.3.1.1.8.1', 'Sim'),
#  (83953, '3.4.3.1.1.8.2', 'Não'),
#  (83954, '3.4.3.1.1.9', 'Variação no número de funcionários'),
#  (83955, '3.4.3.1.1.9.1', 'Houve redução'),
#  (83956, '3.4.3.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (83957, '3.4.3.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (83958, '3.4.3.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (83959, '3.4.3.1.1.9.1.4', 'Não soube responder'),
#  (83960, '3.4.3.1.1.9.2', 'Não houve mudança'),
#  (83961, '3.4.3.1.1.9.3', 'Houve aumento'),
#  (83962, '3.4.3.1.1.9.4', 'Não soube responder'),
#  (83963, '3.4.3.1.2', 'Temporariamente fechada'),
#  (83964, '3.4.3.1.2.1', 'Percentual em relação ao número de empresas'),
#  (83965, '3.4.3.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83966, '3.4.3.1.2.2.1', 'Sim'),
#  (83967, '3.4.3.1.2.2.2', 'Não'),
#  (83968, '3.4.3.1.2.2.3', 'Não soube responder'),
#  (83969, '3.4.3.1.3', 'Fechada em definitivo'),
#  (83970, '3.4.3.1.3.1', 'Percentual em relação ao número de empresas'),
#  (83971, '3.4.3.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (83972, '3.4.3.1.3.2.1', 'Sim'),
#  (83973, '3.4.3.1.3.2.2', 'Não'),
#  (83974, '3.4.3.1.3.2.3', 'Não soube responder'),
#  (83975, '3.4.4', 'Profissionais, administrativos e complementares'),
#  (83976, '3.4.4.1', 'Situação operacional'),
#  (83977,
#   '3.4.4.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (83978, '3.4.4.1.1.1', 'Percentual em relação ao número de empresas'),
#  (83979, '3.4.4.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (83980, '3.4.4.1.1.2.1', 'Impacto negativo'),
#  (83981, '3.4.4.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (83982, '3.4.4.1.1.2.3', 'Impacto positivo'),
#  (83983, '3.4.4.1.1.2.4', 'Não soube responder'),
#  (83984,
#   '3.4.4.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (83985, '3.4.4.1.1.3.1', 'Impacto negativo'),
#  (83986, '3.4.4.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (83987, '3.4.4.1.1.3.3', 'Impacto positivo'),
#  (83988, '3.4.4.1.1.3.4', 'Não soube responder'),
#  (83989,
#   '3.4.4.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (83990, '3.4.4.1.1.4.1', 'Impacto negativo'),
#  (83991, '3.4.4.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (83992, '3.4.4.1.1.4.3', 'Impacto positivo'),
#  (83993, '3.4.4.1.1.4.4', 'Não soube responder'),
#  (83994,
#   '3.4.4.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (83995, '3.4.4.1.1.5.1', 'Impacto negativo'),
#  (83996, '3.4.4.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (83997, '3.4.4.1.1.5.3', 'Impacto positivo'),
#  (83998, '3.4.4.1.1.5.4', 'Não soube responder'),
#  (83999,
#   '3.4.4.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (84000, '3.4.4.1.1.6.1', 'Impacto negativo'),
#  (84001, '3.4.4.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (84002, '3.4.4.1.1.6.3', 'Impacto positivo'),
#  (84003, '3.4.4.1.1.6.4', 'Não soube responder'),
#  (84004,
#   '3.4.4.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84005,
#   '3.4.4.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (84006,
#   '3.4.4.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (84007, '3.4.4.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (84008, '3.4.4.1.1.7.3.1', 'Com apoio governamental'),
#  (84009, '3.4.4.1.1.7.3.2', 'Sem apoio governamental'),
#  (84010,
#   '3.4.4.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (84011, '3.4.4.1.1.7.4.1', 'Com apoio governamental'),
#  (84012, '3.4.4.1.1.7.4.2', 'Sem apoio governamental'),
#  (84013,
#   '3.4.4.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (84014, '3.4.4.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (84015,
#   '3.4.4.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (84016, '3.4.4.1.1.7.8', 'Não adotou nenhuma medida'),
#  (84017, '3.4.4.1.1.7.9', 'Outras medidas'),
#  (84018, '3.4.4.1.1.7.10', 'Não soube responder'),
#  (84019,
#   '3.4.4.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84020, '3.4.4.1.1.8.1', 'Sim'),
#  (84021, '3.4.4.1.1.8.2', 'Não'),
#  (84022, '3.4.4.1.1.9', 'Variação no número de funcionários'),
#  (84023, '3.4.4.1.1.9.1', 'Houve redução'),
#  (84024, '3.4.4.1.1.9.1.1', 'Superior a 50% do quadro de pessoal'),
#  (84025, '3.4.4.1.1.9.1.2', 'Entre 25% e 50% do quadro de pessoal'),
#  (84026, '3.4.4.1.1.9.1.3', 'Inferior a 25% do quadro de pessoal'),
#  (84027, '3.4.4.1.1.9.1.4', 'Não soube responder'),
#  (84028, '3.4.4.1.1.9.2', 'Não houve mudança'),
#  (84029, '3.4.4.1.1.9.3', 'Houve aumento'),
#  (84030, '3.4.4.1.1.9.4', 'Não soube responder'),
#  (84031, '3.4.4.1.2', 'Temporariamente fechada'),
#  (84032, '3.4.4.1.2.1', 'Percentual em relação ao número de empresas'),
#  (84033, '3.4.4.1.2.2', 'Fechamento devido à pandemia da COVID-19'),
#  (84034, '3.4.4.1.2.2.1', 'Sim'),
#  (84035, '3.4.4.1.2.2.2', 'Não'),
#  (84036, '3.4.4.1.2.2.3', 'Não soube responder'),
#  (84037, '3.4.4.1.3', 'Fechada em definitivo'),
#  (84038, '3.4.4.1.3.1', 'Percentual em relação ao número de empresas'),
#  (84039, '3.4.4.1.3.2', 'Fechamento devido à pandemia da COVID-19'),
#  (84040, '3.4.4.1.3.2.1', 'Sim'),
#  (84041, '3.4.4.1.3.2.2', 'Não'),
#  (84042, '3.4.4.1.3.2.3', 'Não soube responder'),
#  (84043,
#   '3.4.5',
#   'Transportes, serviços auxiliares aos transportes e correio'),
#  (84044, '3.4.5.1', 'Situação operacional'),
#  (84045,
#   '3.4.5.1.1',
#   'Aberta, mesmo que parcialmente, em produção ou funcionamento'),
#  (84046, '3.4.5.1.1.1', 'Percentual em relação ao número de empresas'),
#  (84047, '3.4.5.1.1.2', 'Impacto geral causado pela pandemia da COVID-19'),
#  (84048, '3.4.5.1.1.2.1', 'Impacto negativo'),
#  (84049, '3.4.5.1.1.2.2', 'Impacto pequeno ou inexistente'),
#  (84050, '3.4.5.1.1.2.3', 'Impacto positivo'),
#  (84051, '3.4.5.1.1.2.4', 'Não soube responder'),
#  (84052,
#   '3.4.5.1.1.3',
#   'Impacto na venda de produtos ou serviços comercializados'),
#  (84053, '3.4.5.1.1.3.1', 'Impacto negativo'),
#  (84054, '3.4.5.1.1.3.2', 'Impacto pequeno ou inexistente'),
#  (84055, '3.4.5.1.1.3.3', 'Impacto positivo'),
#  (84056, '3.4.5.1.1.3.4', 'Não soube responder'),
#  (84057,
#   '3.4.5.1.1.4',
#   'Impacto na fabricação de produtos ou atendimento aos clientes'),
#  (84058, '3.4.5.1.1.4.1', 'Impacto negativo'),
#  (84059, '3.4.5.1.1.4.2', 'Impacto pequeno ou inexistente'),
#  (84060, '3.4.5.1.1.4.3', 'Impacto positivo'),
#  (84061, '3.4.5.1.1.4.4', 'Não soube responder'),
#  (84062,
#   '3.4.5.1.1.5',
#   'Impacto sobre o acesso aos fornecedores de insumos, matérias-primas ou mercadorias'),
#  (84063, '3.4.5.1.1.5.1', 'Impacto negativo'),
#  (84064, '3.4.5.1.1.5.2', 'Impacto pequeno ou inexistente'),
#  (84065, '3.4.5.1.1.5.3', 'Impacto positivo'),
#  (84066, '3.4.5.1.1.5.4', 'Não soube responder'),
#  (84067,
#   '3.4.5.1.1.6',
#   'Impacto sobre a capacidade de realizar pagamentos de rotina'),
#  (84068, '3.4.5.1.1.6.1', 'Impacto negativo'),
#  (84069, '3.4.5.1.1.6.2', 'Impacto pequeno ou inexistente'),
#  (84070, '3.4.5.1.1.6.3', 'Impacto positivo'),
#  (84071, '3.4.5.1.1.6.4', 'Não soube responder'),
#  (84072,
#   '3.4.5.1.1.7',
#   'Medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84073,
#   '3.4.5.1.1.7.1',
#   'Criou ou passou a comercializar novos produtos ou serviços'),
#  (84074,
#   '3.4.5.1.1.7.2',
#   'Alterou o método de entrega de produtos ou serviços, incluindo a mudança para serviços online'),
#  (84075, '3.4.5.1.1.7.3', 'Adiou o pagamento de impostos'),
#  (84076, '3.4.5.1.1.7.3.1', 'Com apoio governamental'),
#  (84077, '3.4.5.1.1.7.3.2', 'Sem apoio governamental'),
#  (84078,
#   '3.4.5.1.1.7.4',
#   'Obteve linha de crédito emergencial para pagamento da folha salarial'),
#  (84079, '3.4.5.1.1.7.4.1', 'Com apoio governamental'),
#  (84080, '3.4.5.1.1.7.4.2', 'Sem apoio governamental'),
#  (84081,
#   '3.4.5.1.1.7.5',
#   'Adotou trabalho domiciliar (teletrabalho, trabalho remoto e trabalho à distância) para os funcionários'),
#  (84082, '3.4.5.1.1.7.6', 'Antecipou férias dos funcionários'),
#  (84083,
#   '3.4.5.1.1.7.7',
#   'Promoveu campanhas de informação e prevenção e adotou medidas adicionais de higiene'),
#  (84084, '3.4.5.1.1.7.8', 'Não adotou nenhuma medida'),
#  (84085, '3.4.5.1.1.7.9', 'Outras medidas'),
#  (84086, '3.4.5.1.1.7.10', 'Não soube responder'),
#  (84087,
#   '3.4.5.1.1.8',
#   'Apoio governamental a pelo menos uma das medidas adotadas em relação aos impactos causados pela pandemia da COVID-19'),
#  (84088, '3.4.5.1.1.8.1', 'Sim'),
#  ...]

# %%
# Cria DF com os detalhes de cada indicador

df = pd.DataFrame(data=teste_df)
df.columns = ['id_indicador','arvore_indicador','descri_indicador']

# %%
df['nivel_indicador'] = df['arvore_indicador'].str.count('\.') + 1

# %%
df['nivel_indicador'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int64)

# %%
df
# Out:
#       id_indicador arvore_indicador  \
# 0            84179                1
# 1            84180              1.1
# 2            84181            1.1.1
# 3            84182          1.1.1.1
# 4            84183          1.1.1.2
# ...            ...              ...
# 1085         84174      3.4.6.1.3.1
# 1086         84175      3.4.6.1.3.2
# 1087         84176    3.4.6.1.3.2.1
# 1088         84177    3.4.6.1.3.2.2
# 1089         84178    3.4.6.1.3.2.3
#
#                                        descri_indicador  nivel_indicador
# 0                                                 Total                1
# 1                                  Situação operacional                2
# 2     Aberta, mesmo que parcialmente, em produção ou...                3
# 3           Percentual em relação ao número de empresas                4
# 4       Impacto geral causado pela pandemia da COVID-19                4
# ...                                                 ...              ...
# 1085        Percentual em relação ao número de empresas                6
# 1086           Fechamento devido à pandemia da COVID-19                6
# 1087                                                Sim                7
# 1088                                                Não                7
# 1089                                Não soube responder                7
#
# [1090 rows x 4 columns]

# %%
df[df['arvore_indicador']=='1.1.1.7.10']
# Out:
#     id_indicador arvore_indicador     descri_indicador  nivel_indicador
# 43         84222       1.1.1.7.10  Não soube responder                5

# %% [markdown]
# ### 4. Concat full name
#
# * Concatena o nome do nível-pai no nome de cada indicador de nível-filho
# * Cria um dicionário que ao final será mapeado para a coluna "nome_completo_indicador"

# %%
# Pega os primeiros conjuntos de números antes do último ponto final (ou seja, a árvore do pai)

s = '1.1.1.7.9' # "1.1.1.7.10", "1.1.1.7.9", "1.1.1.7"
s.rsplit('.', 1)[0]
# Out:
# '1.1.1.7'

# %%
def concat_parent_name_by_level(df):
    k = df['nivel_indicador'].max() + 1
    mydict = {}
    for i,row in df[df['nivel_indicador']==1].iterrows():
        mydict[row.arvore_indicador] = row.descri_indicador
    for j in range(2,k):
        for i,row in df[df['nivel_indicador']==j].iterrows():
            mydict[row.arvore_indicador] = mydict[row.arvore_indicador.rsplit('.', 1)[0]] + ' - ' + row.descri_indicador
        j += 1
    return mydict

# %%
# Adiciona coluna nome_completo_indicador

mydict = concat_parent_name_by_level(df)
df['nome_completo_indicador'] = df['arvore_indicador'].map(mydict)

# %%
df
# Out:
#       id_indicador arvore_indicador  \
# 0            84179                1
# 1            84180              1.1
# 2            84181            1.1.1
# 3            84182          1.1.1.1
# 4            84183          1.1.1.2
# ...            ...              ...
# 1085         84174      3.4.6.1.3.1
# 1086         84175      3.4.6.1.3.2
# 1087         84176    3.4.6.1.3.2.1
# 1088         84177    3.4.6.1.3.2.2
# 1089         84178    3.4.6.1.3.2.3
#
#                                        descri_indicador  nivel_indicador  \
# 0                                                 Total                1
# 1                                  Situação operacional                2
# 2     Aberta, mesmo que parcialmente, em produção ou...                3
# 3           Percentual em relação ao número de empresas                4
# 4       Impacto geral causado pela pandemia da COVID-19                4
# ...                                                 ...              ...
# 1085        Percentual em relação ao número de empresas                6
# 1086           Fechamento devido à pandemia da COVID-19                6
# 1087                                                Sim                7
# 1088                                                Não                7
# 1089                                Não soube responder                7
#
#                                 nome_completo_indicador
# 0                                                 Total
# 1                          Total - Situação operacional
# 2     Total - Situação operacional - Aberta, mesmo q...
# 3     Total - Situação operacional - Aberta, mesmo q...
# 4     Total - Situação operacional - Aberta, mesmo q...
# ...                                                 ...
# 1085  Atividade - Serviços - Outros serviços - Situa...
# 1086  Atividade - Serviços - Outros serviços - Situa...
# 1087  Atividade - Serviços - Outros serviços - Situa...
# 1088  Atividade - Serviços - Outros serviços - Situa...
# 1089  Atividade - Serviços - Outros serviços - Situa...
#
# [1090 rows x 5 columns]

# %% [markdown]
# ### 5. Export details ind
#
# Para fazer um loop com todas as pesquisas, rodei no PyCharm

# %%
# n_pesquisa = 10096

# %%
# df.to_csv(path_data+'prepared/details_ind_ibge/details_ind_pesquisa_'+str(n_pesquisa)+'.csv', 
#           index=False, sep=';', encoding='utf-8')
