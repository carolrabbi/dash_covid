# %% [markdown]
# ### Calcula correlação letalidade x IBGE municipal indexes
# (Spark)
#
# * Inputs:
#     * datasets/prepared/df_ind_ibge_complete/ (parquet)
#     * datasets/prepared/covid_complete/ (parquet)
# * Outputs:
#     * datasets/correlations_full.csv

# %%
# Spark
import findspark
findspark.init()

from pyspark.sql import SparkSession
import pyspark.sql.functions as f
import pyspark.sql.types as t
from pyspark.sql.window import Window

spark = SparkSession \
            .builder \
            .config("spark.sql.broadcastTimeout", "360000") \
            .config('spark.sql.execution.arrow.enabled', 'false') \
            .config("spark.driver.memory", '14G') \
            .config("spark.executor.memory", '14G') \
            .config("spark.driver.maxResultSize", '4G') \
            .getOrCreate()

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import StandardScaler
from pyspark.ml.linalg import Vectors
from pyspark.ml import Pipeline

# %% [markdown]
# ### 0. Constantes

# %%
main_path = 'D:/data_dash_covid/datasets/'

# %%
# Última data disponível do dado
data_max = '2020-10-24'

# %% [markdown]
# ### 1. Read data

# %%
df_covid_complete = spark.read.parquet(main_path+'prepared/df_covid_complete/')\
                         .filter(f.col('Data') == f.lit(data_max)) \
                         .select('Município_Cod','Casos_Cumul','Mortes_Cumul',)\
                         .withColumn('Taxa_Letalidade', f.round(f.col('Mortes_Cumul') / f.col('Casos_Cumul'), 4))\
                         .withColumn('Casos_Cumul', f.col('Casos_Cumul').cast('int'))\
                         .withColumn('Mortes_Cumul', f.col('Mortes_Cumul').cast('int'))

# %%
df_ind_ibge_complete = spark.read.parquet(main_path+'prepared/df_ind_ibge_complete/')

# %%
df_ind_ibge_complete.printSchema()
# Out:
# root
#  |-- id_indicador: integer (nullable = true)
#  |-- periodo: integer (nullable = true)
#  |-- id_pesquisa: integer (nullable = true)
#  |-- nome_indicador: string (nullable = true)
#  |-- nome_pesquisa: string (nullable = true)
#  |-- arvore_indicador: string (nullable = true)
#  |-- descri_indicador: string (nullable = true)
#  |-- nivel_indicador: string (nullable = true)
#  |-- nome_completo_indicador: string (nullable = true)
#  |-- id_cidade: integer (nullable = true)
#  |-- resultado: string (nullable = true)

# %% [markdown]
# ### 2. Join data
#
# Covid (casos, mortes e letalidade) versus os indicadores IBGE

# %%
df = df_ind_ibge_complete.select('id_cidade','id_indicador','resultado')\
                         .groupBy('id_cidade').pivot('id_indicador').agg(f.mean('resultado'))\
                         .withColumnRenamed('id_cidade','Município_Cod')\
                         .join(df_covid_complete, 'Município_Cod', 'inner')\
                         .drop('Município_Cod')

# %%
print(df.count(), len(df.columns))
# Out:
# 5570 282

# %%
df.printSchema()
# Out:
# root
#  |-- 5903: double (nullable = true)
#  |-- 5908: double (nullable = true)
#  |-- 5913: double (nullable = true)
#  |-- 5924: double (nullable = true)
#  |-- 5929: double (nullable = true)
#  |-- 5934: double (nullable = true)
#  |-- 5945: double (nullable = true)
#  |-- 5950: double (nullable = true)
#  |-- 5955: double (nullable = true)
#  |-- 15752: double (nullable = true)
#  |-- 15754: double (nullable = true)
#  |-- 15755: double (nullable = true)
#  |-- 15756: double (nullable = true)
#  |-- 15760: double (nullable = true)
#  |-- 15765: double (nullable = true)
#  |-- 15769: double (nullable = true)
#  |-- 15773: double (nullable = true)
#  |-- 15777: double (nullable = true)
#  |-- 15781: double (nullable = true)
#  |-- 15785: double (nullable = true)
#  |-- 15789: double (nullable = true)
#  |-- 15793: double (nullable = true)
#  |-- 15797: double (nullable = true)
#  |-- 15801: double (nullable = true)
#  |-- 15805: double (nullable = true)
#  |-- 15809: double (nullable = true)
#  |-- 15813: double (nullable = true)
#  |-- 15817: double (nullable = true)
#  |-- 15820: double (nullable = true)
#  |-- 15824: double (nullable = true)
#  |-- 15829: double (nullable = true)
#  |-- 15833: double (nullable = true)
#  |-- 15837: double (nullable = true)
#  |-- 21636: double (nullable = true)
#  |-- 21637: double (nullable = true)
#  |-- 21638: double (nullable = true)
#  |-- 21639: double (nullable = true)
#  |-- 21640: double (nullable = true)
#  |-- 21641: double (nullable = true)
#  |-- 21642: double (nullable = true)
#  |-- 21643: double (nullable = true)
#  |-- 21644: double (nullable = true)
#  |-- 21645: double (nullable = true)
#  |-- 21646: double (nullable = true)
#  |-- 21647: double (nullable = true)
#  |-- 21906: double (nullable = true)
#  |-- 21907: double (nullable = true)
#  |-- 21910: double (nullable = true)
#  |-- 21911: double (nullable = true)
#  |-- 21912: double (nullable = true)
#  |-- 21913: double (nullable = true)
#  |-- 28120: double (nullable = true)
#  |-- 28122: double (nullable = true)
#  |-- 28123: double (nullable = true)
#  |-- 28124: double (nullable = true)
#  |-- 28125: double (nullable = true)
#  |-- 28126: double (nullable = true)
#  |-- 28127: double (nullable = true)
#  |-- 28128: double (nullable = true)
#  |-- 28129: double (nullable = true)
#  |-- 28130: double (nullable = true)
#  |-- 28131: double (nullable = true)
#  |-- 28132: double (nullable = true)
#  |-- 28133: double (nullable = true)
#  |-- 28135: double (nullable = true)
#  |-- 28136: double (nullable = true)
#  |-- 28137: double (nullable = true)
#  |-- 28139: double (nullable = true)
#  |-- 28140: double (nullable = true)
#  |-- 28141: double (nullable = true)
#  |-- 28142: double (nullable = true)
#  |-- 28143: double (nullable = true)
#  |-- 28144: double (nullable = true)
#  |-- 28145: double (nullable = true)
#  |-- 28147: double (nullable = true)
#  |-- 28148: double (nullable = true)
#  |-- 28149: double (nullable = true)
#  |-- 28150: double (nullable = true)
#  |-- 28151: double (nullable = true)
#  |-- 28152: double (nullable = true)
#  |-- 28154: double (nullable = true)
#  |-- 28155: double (nullable = true)
#  |-- 28157: double (nullable = true)
#  |-- 28158: double (nullable = true)
#  |-- 28159: double (nullable = true)
#  |-- 28160: double (nullable = true)
#  |-- 28161: double (nullable = true)
#  |-- 28162: double (nullable = true)
#  |-- 28163: double (nullable = true)
#  |-- 28164: double (nullable = true)
#  |-- 28166: double (nullable = true)
#  |-- 28167: double (nullable = true)
#  |-- 28168: double (nullable = true)
#  |-- 28169: double (nullable = true)
#  |-- 28170: double (nullable = true)
#  |-- 28171: double (nullable = true)
#  |-- 28172: double (nullable = true)
#  |-- 28173: double (nullable = true)
#  |-- 28174: double (nullable = true)
#  |-- 28231: double (nullable = true)
#  |-- 28232: double (nullable = true)
#  |-- 28233: double (nullable = true)
#  |-- 28234: double (nullable = true)
#  |-- 28235: double (nullable = true)
#  |-- 28236: double (nullable = true)
#  |-- 28237: double (nullable = true)
#  |-- 28239: double (nullable = true)
#  |-- 28240: double (nullable = true)
#  |-- 28241: double (nullable = true)
#  |-- 28242: double (nullable = true)
#  |-- 28243: double (nullable = true)
#  |-- 28244: double (nullable = true)
#  |-- 28245: double (nullable = true)
#  |-- 28246: double (nullable = true)
#  |-- 28247: double (nullable = true)
#  |-- 28249: double (nullable = true)
#  |-- 28257: double (nullable = true)
#  |-- 28266: double (nullable = true)
#  |-- 28267: double (nullable = true)
#  |-- 28268: double (nullable = true)
#  |-- 28269: double (nullable = true)
#  |-- 28270: double (nullable = true)
#  |-- 28271: double (nullable = true)
#  |-- 28280: double (nullable = true)
#  |-- 28288: double (nullable = true)
#  |-- 28297: double (nullable = true)
#  |-- 28298: double (nullable = true)
#  |-- 28299: double (nullable = true)
#  |-- 28301: double (nullable = true)
#  |-- 28302: double (nullable = true)
#  |-- 28304: double (nullable = true)
#  |-- 28305: double (nullable = true)
#  |-- 28306: double (nullable = true)
#  |-- 28307: double (nullable = true)
#  |-- 28308: double (nullable = true)
#  |-- 28309: double (nullable = true)
#  |-- 28310: double (nullable = true)
#  |-- 28311: double (nullable = true)
#  |-- 28313: double (nullable = true)
#  |-- 28314: double (nullable = true)
#  |-- 28315: double (nullable = true)
#  |-- 28316: double (nullable = true)
#  |-- 28317: double (nullable = true)
#  |-- 28318: double (nullable = true)
#  |-- 29166: double (nullable = true)
#  |-- 29167: double (nullable = true)
#  |-- 29168: double (nullable = true)
#  |-- 29169: double (nullable = true)
#  |-- 29170: double (nullable = true)
#  |-- 29171: double (nullable = true)
#  |-- 29748: double (nullable = true)
#  |-- 29749: double (nullable = true)
#  |-- 29750: double (nullable = true)
#  |-- 29751: double (nullable = true)
#  |-- 29752: double (nullable = true)
#  |-- 29753: double (nullable = true)
#  |-- 29754: double (nullable = true)
#  |-- 29755: double (nullable = true)
#  |-- 29756: double (nullable = true)
#  |-- 30255: double (nullable = true)
#  |-- 30279: double (nullable = true)
#  |-- 46997: double (nullable = true)
#  |-- 46998: double (nullable = true)
#  |-- 46999: double (nullable = true)
#  |-- 47001: double (nullable = true)
#  |-- 47002: double (nullable = true)
#  |-- 47004: double (nullable = true)
#  |-- 47006: double (nullable = true)
#  |-- 47007: double (nullable = true)
#  |-- 47008: double (nullable = true)
#  |-- 47009: double (nullable = true)
#  |-- 47010: double (nullable = true)
#  |-- 47012: double (nullable = true)
#  |-- 47013: double (nullable = true)
#  |-- 47014: double (nullable = true)
#  |-- 47015: double (nullable = true)
#  |-- 47018: double (nullable = true)
#  |-- 47019: double (nullable = true)
#  |-- 47020: double (nullable = true)
#  |-- 47022: double (nullable = true)
#  |-- 47023: double (nullable = true)
#  |-- 47024: double (nullable = true)
#  |-- 47374: double (nullable = true)
#  |-- 60409: double (nullable = true)
#  |-- 76821: double (nullable = true)
#  |-- 76822: double (nullable = true)
#  |-- 76838: double (nullable = true)
#  |-- 76839: double (nullable = true)
#  |-- 76866: double (nullable = true)
#  |-- 76867: double (nullable = true)
#  |-- 76868: double (nullable = true)
#  |-- 76869: double (nullable = true)
#  |-- 76875: double (nullable = true)
#  |-- 76877: double (nullable = true)
#  |-- 76878: double (nullable = true)
#  |-- 76879: double (nullable = true)
#  |-- 76880: double (nullable = true)
#  |-- 76881: double (nullable = true)
#  |-- 76883: double (nullable = true)
#  |-- 76884: double (nullable = true)
#  |-- 76885: double (nullable = true)
#  |-- 76886: double (nullable = true)
#  |-- 76887: double (nullable = true)
#  |-- 76890: double (nullable = true)
#  |-- 76892: double (nullable = true)
#  |-- 76894: double (nullable = true)
#  |-- 76896: double (nullable = true)
#  |-- 76899: double (nullable = true)
#  |-- 76906: double (nullable = true)
#  |-- 76908: double (nullable = true)
#  |-- 76910: double (nullable = true)
#  |-- 76912: double (nullable = true)
#  |-- 76915: double (nullable = true)
#  |-- 76916: double (nullable = true)
#  |-- 76918: double (nullable = true)
#  |-- 76920: double (nullable = true)
#  |-- 76921: double (nullable = true)
#  |-- 76922: double (nullable = true)
#  |-- 76923: double (nullable = true)
#  |-- 76924: double (nullable = true)
#  |-- 76925: double (nullable = true)
#  |-- 76926: double (nullable = true)
#  |-- 76927: double (nullable = true)
#  |-- 76928: double (nullable = true)
#  |-- 76929: double (nullable = true)
#  |-- 76930: double (nullable = true)
#  |-- 76931: double (nullable = true)
#  |-- 76932: double (nullable = true)
#  |-- 76933: double (nullable = true)
#  |-- 76934: double (nullable = true)
#  |-- 76936: double (nullable = true)
#  |-- 76937: double (nullable = true)
#  |-- 76938: double (nullable = true)
#  |-- 76939: double (nullable = true)
#  |-- 76940: double (nullable = true)
#  |-- 76941: double (nullable = true)
#  |-- 77861: double (nullable = true)
#  |-- 77862: double (nullable = true)
#  |-- 77863: double (nullable = true)
#  |-- 77881: double (nullable = true)
#  |-- 77882: double (nullable = true)
#  |-- 77887: double (nullable = true)
#  |-- 77888: double (nullable = true)
#  |-- 77893: double (nullable = true)
#  |-- 77894: double (nullable = true)
#  |-- 77899: double (nullable = true)
#  |-- 77900: double (nullable = true)
#  |-- 77901: double (nullable = true)
#  |-- 77902: double (nullable = true)
#  |-- 77903: double (nullable = true)
#  |-- 77904: double (nullable = true)
#  |-- 77905: double (nullable = true)
#  |-- 77906: double (nullable = true)
#  |-- 77907: double (nullable = true)
#  |-- 77908: double (nullable = true)
#  |-- 77909: double (nullable = true)
#  |-- 77910: double (nullable = true)
#  |-- 77911: double (nullable = true)
#  |-- 77912: double (nullable = true)
#  |-- 77913: double (nullable = true)
#  |-- 77914: double (nullable = true)
#  |-- 77927: double (nullable = true)
#  |-- 77928: double (nullable = true)
#  |-- 78122: double (nullable = true)
#  |-- 78159: double (nullable = true)
#  |-- 78160: double (nullable = true)
#  |-- 78161: double (nullable = true)
#  |-- 78162: double (nullable = true)
#  |-- 78163: double (nullable = true)
#  |-- 78164: double (nullable = true)
#  |-- 78165: double (nullable = true)
#  |-- 78166: double (nullable = true)
#  |-- 78167: double (nullable = true)
#  |-- 78168: double (nullable = true)
#  |-- 78169: double (nullable = true)
#  |-- 78170: double (nullable = true)
#  |-- 78187: double (nullable = true)
#  |-- 78192: double (nullable = true)
#  |-- 82270: double (nullable = true)
#  |-- Casos_Cumul: integer (nullable = true)
#  |-- Mortes_Cumul: integer (nullable = true)
#  |-- Taxa_Letalidade: double (nullable = true)

# %% [markdown]
# ### 3. Correlação para Casos, Mortes, Letalidade
#
# Based on [here](https://databricks.com/blog/2015/06/02/statistical-and-mathematical-functions-with-dataframes-in-spark.html) and [here](https://spark.apache.org/docs/2.2.0/ml-statistics.html)

# %%
dict_corr = {}
dict_corr['Mortes'] = {}
dict_corr['Casos'] = {}
dict_corr['Letalidade'] = {}

for c in df.columns:
    if c not in ['Casos_Cumul','Mortes_Cumul','Taxa_Letalidade']:
        print(c)
        try:
            dict_corr['Casos'][c] = df.stat.corr(c, 'Casos_Cumul')
            dict_corr['Mortes'][c] = df.stat.corr(c, 'Mortes_Cumul')
            dict_corr['Letalidade'][c] = df.stat.corr(c, 'Taxa_Letalidade')
        except:
            print('Não foi possível calcular correlação com indicador {}'.format(c))
# Out:
# 5903
# 5908
# 5913
# 5924
# 5929
# 5934
# 5945
# 5950
# 5955
# 15752
# 15754
# 15755
# 15756
# 15760
# 15765
# 15769
# 15773
# 15777
# 15781
# 15785
# 15789
# 15793
# 15797
# 15801
# 15805
# 15809
# 15813
# 15817
# 15820
# 15824
# 15829
# 15833
# 15837
# 21636
# 21637
# 21638
# 21639
# 21640
# 21641
# 21642
# 21643
# 21644
# 21645
# 21646
# 21647
# 21906
# 21907
# 21910
# 21911
# 21912
# 21913
# 28120
# 28122
# 28123
# 28124
# 28125
# 28126
# 28127
# 28128
# 28129
# 28130
# 28131
# 28132
# 28133
# 28135
# 28136
# 28137
# 28139
# 28140
# 28141
# 28142
# 28143
# 28144
# 28145
# 28147
# 28148
# 28149
# 28150
# 28151
# 28152
# 28154
# 28155
# 28157
# 28158
# 28159
# 28160
# 28161
# 28162
# 28163
# 28164
# 28166
# 28167
# 28168
# 28169
# 28170
# 28171
# 28172
# 28173
# 28174
# 28231
# 28232
# 28233
# 28234
# 28235
# 28236
# 28237
# 28239
# 28240
# 28241
# 28242
# 28243
# 28244
# 28245
# 28246
# 28247
# 28249
# 28257
# 28266
# 28267
# 28268
# 28269
# 28270
# 28271
# 28280
# 28288
# 28297
# 28298
# 28299
# 28301
# 28302
# 28304
# 28305
# 28306
# 28307
# 28308
# 28309
# 28310
# 28311
# 28313
# 28314
# 28315
# 28316
# 28317
# 28318
# 29166
# 29167
# 29168
# 29169
# 29170
# 29171
# 29748
# 29749
# 29750
# 29751
# 29752
# 29753
# 29754
# 29755
# 29756
# 30255
# 30279
# 46997
# 46998
# 46999
# 47001
# 47002
# 47004
# 47006
# 47007
# 47008
# 47009
# 47010
# 47012
# 47013
# 47014
# 47015
# 47018
# 47019
# 47020
# 47022
# 47023
# 47024
# 47374
# 60409
# 76821
# 76822
# 76838
# Não foi possível calcular correlação com indicador 76838
# 76839
# Não foi possível calcular correlação com indicador 76839
# 76866
# 76867
# 76868
# 76869
# 76875
# 76877
# 76878
# 76879
# 76880
# 76881
# 76883
# 76884
# 76885
# 76886
# 76887
# 76890
# 76892
# 76894
# 76896
# 76899
# 76906
# Não foi possível calcular correlação com indicador 76906
# 76908
# Não foi possível calcular correlação com indicador 76908
# 76910
# Não foi possível calcular correlação com indicador 76910
# 76912
# Não foi possível calcular correlação com indicador 76912
# 76915
# Não foi possível calcular correlação com indicador 76915
# 76916
# Não foi possível calcular correlação com indicador 76916
# 76918
# Não foi possível calcular correlação com indicador 76918
# 76920
# Não foi possível calcular correlação com indicador 76920
# 76921
# Não foi possível calcular correlação com indicador 76921
# 76922
# Não foi possível calcular correlação com indicador 76922
# 76923
# Não foi possível calcular correlação com indicador 76923
# 76924
# Não foi possível calcular correlação com indicador 76924
# 76925
# Não foi possível calcular correlação com indicador 76925
# 76926
# Não foi possível calcular correlação com indicador 76926
# 76927
# Não foi possível calcular correlação com indicador 76927
# 76928
# Não foi possível calcular correlação com indicador 76928
# 76929
# Não foi possível calcular correlação com indicador 76929
# 76930
# Não foi possível calcular correlação com indicador 76930
# 76931
# Não foi possível calcular correlação com indicador 76931
# 76932
# Não foi possível calcular correlação com indicador 76932
# 76933
# Não foi possível calcular correlação com indicador 76933
# 76934
# Não foi possível calcular correlação com indicador 76934
# 76936
# Não foi possível calcular correlação com indicador 76936
# 76937
# Não foi possível calcular correlação com indicador 76937
# 76938
# Não foi possível calcular correlação com indicador 76938
# 76939
# Não foi possível calcular correlação com indicador 76939
# 76940
# Não foi possível calcular correlação com indicador 76940
# 76941
# Não foi possível calcular correlação com indicador 76941
# 77861
# Não foi possível calcular correlação com indicador 77861
# 77862
# Não foi possível calcular correlação com indicador 77862
# 77863
# Não foi possível calcular correlação com indicador 77863
# 77881
# Não foi possível calcular correlação com indicador 77881
# 77882
# Não foi possível calcular correlação com indicador 77882
# 77887
# Não foi possível calcular correlação com indicador 77887
# 77888
# Não foi possível calcular correlação com indicador 77888
# 77893
# Não foi possível calcular correlação com indicador 77893
# 77894
# Não foi possível calcular correlação com indicador 77894
# 77899
# Não foi possível calcular correlação com indicador 77899
# 77900
# Não foi possível calcular correlação com indicador 77900
# 77901
# Não foi possível calcular correlação com indicador 77901
# 77902
# Não foi possível calcular correlação com indicador 77902
# 77903
# Não foi possível calcular correlação com indicador 77903
# 77904
# Não foi possível calcular correlação com indicador 77904
# 77905
# Não foi possível calcular correlação com indicador 77905
# 77906
# Não foi possível calcular correlação com indicador 77906
# 77907
# Não foi possível calcular correlação com indicador 77907
# 77908
# Não foi possível calcular correlação com indicador 77908
# 77909
# Não foi possível calcular correlação com indicador 77909
# 77910
# Não foi possível calcular correlação com indicador 77910
# 77911
# Não foi possível calcular correlação com indicador 77911
# 77912
# Não foi possível calcular correlação com indicador 77912
# 77913
# Não foi possível calcular correlação com indicador 77913
# 77914
# Não foi possível calcular correlação com indicador 77914
# 77927
# Não foi possível calcular correlação com indicador 77927
# 77928
# Não foi possível calcular correlação com indicador 77928
# 78122
# Não foi possível calcular correlação com indicador 78122
# 78159
# Não foi possível calcular correlação com indicador 78159
# 78160
# Não foi possível calcular correlação com indicador 78160
# 78161
# Não foi possível calcular correlação com indicador 78161
# 78162
# Não foi possível calcular correlação com indicador 78162
# 78163
# Não foi possível calcular correlação com indicador 78163
# 78164
# Não foi possível calcular correlação com indicador 78164
# 78165
# Não foi possível calcular correlação com indicador 78165
# 78166
# Não foi possível calcular correlação com indicador 78166
# 78167
# Não foi possível calcular correlação com indicador 78167
# 78168
# Não foi possível calcular correlação com indicador 78168
# 78169
# Não foi possível calcular correlação com indicador 78169
# 78170
# Não foi possível calcular correlação com indicador 78170
# 78187
# Não foi possível calcular correlação com indicador 78187
# 78192
# Não foi possível calcular correlação com indicador 78192
# 82270
# Não foi possível calcular correlação com indicador 82270

# %%
corr_values = pd.DataFrame(dict_corr).reset_index()
corr_values.rename(columns={'index':'id_indicador'}, inplace=True)
corr_values = corr_values.round(4)
corr_values
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#     id_indicador  Mortes   Casos  Letalidade
# 0           5903  0.0332  0.0356      0.0259
# 1           5908  0.0404  0.0428      0.0270
# 2           5913  0.0434  0.0440      0.0270
# 3           5924  0.0244  0.0264      0.0252
# 4           5929  0.0319  0.0337      0.0268
# 5           5934  0.0328  0.0328      0.0286
# 6           5945  0.0282  0.0287      0.0300
# 7           5950  0.0399  0.0429      0.0301
# 8           5955  0.0299  0.0297      0.0287
# 9          15752 -0.0012 -0.0018     -0.0003
# 10         15754 -0.0025  0.0020      0.0008
# 11         15755 -0.0024  0.0014      0.0024
# 12         15756 -0.0018  0.0062     -0.0046
# 13         15760 -0.0012 -0.0018     -0.0003
# 14         15765 -0.0028  0.0003      0.0021
# 15         15769 -0.0021  0.0021     -0.0004
# 16         15773 -0.0022 -0.0001      0.0069
# 17         15777 -0.0025  0.0010      0.0032
# 18         15781 -0.0027  0.0009      0.0016
# 19         15785 -0.0019  0.0026      0.0054
# 20         15789 -0.0002  0.0050      0.0001
# 21         15793 -0.0022  0.0039     -0.0051
# 22         15797 -0.0025  0.0037      0.0004
# 23         15801 -0.0046 -0.0009      0.0074
# 24         15805 -0.0019  0.0023      0.0056
# 25         15809 -0.0017  0.0032      0.0084
# 26         15813 -0.0021  0.0033     -0.0044
# 27         15817  0.0003  0.0049      0.0092
# 28         15820 -0.0012 -0.0018     -0.0003
# 29         15824 -0.0028  0.0018     -0.0038
# 30         15829 -0.0024  0.0016      0.0002
# 31         15833 -0.0013  0.0014      0.0148
# 32         15837 -0.0015  0.0031     -0.0077
# 33         21636 -0.0021  0.0034     -0.0039
# 34         21637 -0.0021  0.0033     -0.0057
# 35         21638 -0.0008  0.0048     -0.0045
# 36         21639 -0.0020  0.0066     -0.0032
# 37         21640 -0.0010  0.0083     -0.0065
# 38         21641 -0.0009  0.0074     -0.0048
# 39         21642 -0.0024  0.0038     -0.0030
# 40         21643 -0.0026  0.0016     -0.0010
# 41         21644 -0.0027  0.0009      0.0026
# 42         21645 -0.0027  0.0006      0.0037
# 43         21646 -0.0027  0.0010      0.0024
# 44         21647 -0.0022  0.0017      0.0021
# 45         21906 -0.0020 -0.0029     -0.0157
# 46         21907 -0.0017 -0.0027     -0.0162
# 47         21910 -0.0008 -0.0024     -0.0161
# 48         21911 -0.0013 -0.0026     -0.0150
# 49         21912 -0.0017 -0.0028     -0.0166
# 50         21913 -0.0018 -0.0031     -0.0159
# 51         28120  0.9056  0.9152      0.0330
# 52         28122  0.9034  0.9027      0.0327
# 53         28123  0.8741  0.8930      0.0357
# 54         28124  0.7042  0.7661      0.0178
# 55         28125  0.8633  0.9156      0.0265
# 56         28126  0.8953  0.8873      0.0304
# 57         28127  0.9323  0.8740      0.0386
# 58         28128  0.8816  0.9116      0.0388
# 59         28129  0.7674  0.8266      0.0151
# 60         28130  0.9273  0.9342      0.0403
# 61         28131  0.7002  0.7691      0.0168
# 62         28132  0.8876  0.8968      0.0247
# 63         28133  0.6946  0.7533      0.0081
# 64         28135 -0.0026 -0.0032     -0.0011
# 65         28136 -0.0033 -0.0040     -0.0004
# 66         28137 -0.0032 -0.0038     -0.0004
# 67         28139 -0.0031 -0.0038     -0.0016
# 68         28140 -0.0035 -0.0042      0.0007
# 69         28141 -0.0035 -0.0044      0.0011
# 70         28142 -0.0013 -0.0018      0.0008
# 71         28143 -0.0042 -0.0046     -0.0006
# 72         28144 -0.0035 -0.0043      0.0014
# 73         28145 -0.0027 -0.0035     -0.0028
# 74         28147 -0.0027 -0.0036     -0.0024
# 75         28148 -0.0027 -0.0035     -0.0036
# 76         28149 -0.0025 -0.0036     -0.0006
# 77         28150 -0.0028 -0.0035     -0.0001
# 78         28151 -0.0035 -0.0061      0.0160
# 79         28152 -0.0045 -0.0062      0.0111
# 80         28154 -0.0041 -0.0049      0.0053
# 81         28155 -0.0006 -0.0021      0.0012
# 82         28157 -0.0047 -0.0046      0.0111
# 83         28158 -0.0039 -0.0054      0.0041
# 84         28159 -0.0028 -0.0037     -0.0023
# 85         28160 -0.0034 -0.0036      0.0231
# 86         28161 -0.0008 -0.0007     -0.0131
# 87         28162  0.0049  0.0038      0.0117
# 88         28163  0.0319  0.0338      0.0159
# 89         28164  0.0439  0.0429      0.0177
# 90         28166  0.0342  0.0328      0.0118
# 91         28167  0.0244  0.0267      0.0132
# 92         28168  0.0418  0.0417      0.0153
# 93         28169  0.0233  0.0271      0.0150
# 94         28170  0.0371  0.0350      0.0209
# 95         28171  0.0412  0.0387      0.0193
# 96         28172  0.0240  0.0268      0.0132
# 97         28173  0.0351  0.0341      0.0154
# 98         28174  0.0272  0.0263      0.0153
# 99         28231  0.0217  0.0239      0.0110
# 100        28232  0.0217  0.0240      0.0106
# 101        28233  0.0176  0.0180      0.0155
# 102        28234  0.0621  0.0625      0.0302
# 103        28235  0.0262  0.0351     -0.0043
# 104        28236  0.0540  0.0585      0.0030
# 105        28237  0.0567  0.0554      0.0336
# 106        28239  0.0214  0.0237      0.0103
# 107        28240  0.0254  0.0296      0.0136
# 108        28241  0.0227  0.0249      0.0099
# 109        28242  0.0564  0.0569      0.0245
# 110        28243  0.0580  0.0578      0.0255
# 111        28244  0.0282  0.0293      0.0126
# 112        28245  0.0632  0.0598      0.0181
# 113        28246  0.0512  0.0508      0.0194
# 114        28247  0.0454  0.0484      0.0153
# 115        28249  0.0396  0.0401      0.0170
# 116        28257  0.0319  0.0337      0.0142
# 117        28266  0.0325  0.0341      0.0144
# 118        28267  0.0151  0.0183      0.0076
# 119        28268  0.0443  0.0445      0.0204
# 120        28269  0.0245  0.0263      0.0120
# 121        28270  0.0319  0.0319      0.0172
# 122        28271  0.0267  0.0293      0.0191
# 123        28280  0.0198  0.0227      0.0182
# 124        28288  0.0261  0.0288      0.0156
# 125        28297  0.0193  0.0193      0.0155
# 126        28298  0.0184  0.0188      0.0127
# 127        28299  0.0190  0.0189      0.0188
# 128        28301  0.0167  0.0171      0.0135
# 129        28302  0.0197  0.0194      0.0156
# 130        28304  0.0201  0.0186      0.0147
# 131        28305  0.0220  0.0228      0.0143
# 132        28306  0.0258  0.0260      0.0110
# 133        28307  0.0181  0.0181      0.0101
# 134        28308  0.0180  0.0177      0.0100
# 135        28309  0.0159  0.0158      0.0097
# 136        28310  0.0202  0.0201      0.0131
# 137        28311  0.0265  0.0258      0.0162
# 138        28313  0.0359  0.0371      0.0138
# 139        28314  0.0206  0.0195      0.0129
# 140        28315  0.0435  0.0448      0.0125
# 141        28316  0.0140  0.0161      0.0093
# 142        28317  0.0186  0.0167      0.0171
# 143        28318  0.0198  0.0169      0.0169
# 144        29166  0.0315  0.0301      0.0157
# 145        29167  0.0057  0.0233     -0.0280
# 146        29168  0.0089  0.0036      0.0234
# 147        29169 -0.0176 -0.0344     -0.0060
# 148        29170     NaN     NaN         NaN
# 149        29171  0.0337  0.0329      0.0155
# 150        29748  0.0042  0.0083      0.0053
# 151        29749 -0.0033 -0.0040     -0.0005
# 152        29750  0.0042  0.0083      0.0053
# 153        29751  0.0042  0.0083      0.0053
# 154        29752  0.0042  0.0083      0.0053
# 155        29753  0.0042  0.0083      0.0053
# 156        29754  0.0042  0.0083      0.0053
# 157        29755  0.0042  0.0083      0.0053
# 158        29756  0.0320  0.0338      0.0158
# 159        30255  0.1109  0.1415     -0.0080
# 160        30279 -0.0055 -0.0057     -0.0328
# 161        46997  0.9348  0.9202      0.0346
# 162        46998  0.9341  0.9106      0.0352
# 163        46999  0.9250  0.9170      0.0344
# 164        47001  0.0680  0.0936     -0.0464
# 165        47002  0.0697  0.0977     -0.0256
# 166        47004  0.9286  0.9285      0.0340
# 167        47006  0.0483  0.1137     -0.0428
# 168        47007  0.8232  0.7920      0.0379
# 169        47008  0.9125  0.8910      0.0315
# 170        47009  0.7158  0.8310      0.0312
# 171        47010  0.9311  0.9167      0.0352
# 172        47012  0.0434  0.1060     -0.0429
# 173        47013  0.8435  0.7933      0.0428
# 174        47014  0.9146  0.8810      0.0314
# 175        47015  0.7365  0.8495      0.0318
# 176        47018  0.0461  0.1088     -0.0484
# 177        47019  0.7900  0.7794      0.0371
# 178        47020  0.9204  0.9270      0.0327
# 179        47022  0.9466  0.8659      0.0368
# 180        47023  0.9376  0.8746      0.0347
# 181        47024  0.9255  0.8673      0.0351
# 182        47374  0.0337  0.0347      0.0084
# 183        60409     NaN     NaN         NaN
# 184        76821     NaN     NaN         NaN
# 185        76822     NaN     NaN         NaN
# 186        76866     NaN     NaN         NaN
# 187        76867  0.0122  0.0158     -0.0142
# 188        76868  0.0168  0.0370     -0.0400
# 189        76869     NaN     NaN         NaN
# 190        76875  0.0320  0.0519     -0.0057
# 191        76877     NaN     NaN         NaN
# 192        76878     NaN     NaN         NaN
# 193        76879     NaN     NaN         NaN
# 194        76880     NaN     NaN         NaN
# 195        76881     NaN     NaN         NaN
# 196        76883     NaN     NaN         NaN
# 197        76884     NaN     NaN         NaN
# 198        76885     NaN     NaN         NaN
# 199        76886     NaN     NaN         NaN
# 200        76887     NaN     NaN         NaN
# 201        76890     NaN     NaN         NaN
# 202        76892     NaN     NaN         NaN
# 203        76894     NaN     NaN         NaN
# 204        76896     NaN     NaN         NaN
# 205        76899     NaN     NaN         NaN
# 206        76906     NaN     NaN         NaN

# %%
corr_values.to_csv(main_path+'correlations.csv', index=False)

# %% [markdown]
# #### Refazendo para os faltantes

# %%
ids_faltantes = [76838,76839,76906,76908,76910,76912,76915,76916,76918,76920,76921,76922,76923,76924,76925,76926,76927,
                 76928,76929,76930,76931,76932,76933,76934,76936,76937,76938,76939,76940,76941,77861,77862,77863,77881,
                 77882,77887,77888,77893,77894,77899,77900,77901,77902,77903,77904,77905,77906,77907,77908,77909,77910,
                 77911,77912,77913,77914,77927,77928,78122,78159,78160,78161,78162,78163,78164,78165,78166,78167,78168,
                 78169,78170,78187,78192,82270]

# %%
dict_corr = {}
dict_corr['Mortes'] = {}
dict_corr['Casos'] = {}
dict_corr['Letalidade'] = {}

for i in ids_faltantes:
    c = str(i)
    print(c)
    try:
        dict_corr['Casos'][c] = df.stat.corr(c, 'Casos_Cumul')
        dict_corr['Mortes'][c] = df.stat.corr(c, 'Mortes_Cumul')
        dict_corr['Letalidade'][c] = df.stat.corr(c, 'Taxa_Letalidade')
    except:
        print('Não foi possível calcular correlação com indicador {}'.format(c))
# Out:
# 76838
# 76839
# 76906
# 76908
# 76910
# 76912
# 76915
# 76916
# 76918
# 76920
# 76921
# 76922
# 76923
# 76924
# 76925
# 76926
# 76927
# 76928
# 76929
# 76930
# 76931
# 76932
# 76933
# 76934
# 76936
# 76937
# 76938
# 76939
# 76940
# 76941
# 77861
# 77862
# 77863
# 77881
# 77882
# 77887
# 77888
# 77893
# 77894
# 77899
# 77900
# 77901
# 77902
# 77903
# 77904
# 77905
# 77906
# 77907
# 77908
# 77909
# 77910
# 77911
# 77912
# 77913
# 77914
# 77927
# 77928
# 78122
# 78159
# 78160
# 78161
# 78162
# 78163
# 78164
# 78165
# 78166
# 78167
# 78168
# 78169
# 78170
# 78187
# 78192
# 82270

# %%
corr_values_2 = pd.DataFrame(dict_corr).reset_index()
corr_values_2.rename(columns={'index':'id_indicador'}, inplace=True)
corr_values_2 = corr_values_2.round(4)
corr_values_2
# Out:
#    id_indicador  Mortes   Casos  Letalidade
# 0         76838     NaN     NaN         NaN
# 1         76839     NaN     NaN         NaN
# 2         76906     NaN     NaN         NaN
# 3         76908     NaN     NaN         NaN
# 4         76910     NaN     NaN         NaN
# 5         76912     NaN     NaN         NaN
# 6         76915     NaN     NaN         NaN
# 7         76916     NaN     NaN         NaN
# 8         76918     NaN     NaN         NaN
# 9         76920     NaN     NaN         NaN
# 10        76921     NaN     NaN         NaN
# 11        76922     NaN     NaN         NaN
# 12        76923     NaN     NaN         NaN
# 13        76924     NaN     NaN         NaN
# 14        76925     NaN     NaN         NaN
# 15        76926     NaN     NaN         NaN
# 16        76927     NaN     NaN         NaN
# 17        76928     NaN     NaN         NaN
# 18        76929     NaN     NaN         NaN
# 19        76930     NaN     NaN         NaN
# 20        76931     NaN     NaN         NaN
# 21        76932     NaN     NaN         NaN
# 22        76933     NaN     NaN         NaN
# 23        76934     NaN     NaN         NaN
# 24        76936     NaN     NaN         NaN
# 25        76937 -0.0051 -0.0017     -0.0080
# 26        76938     NaN     NaN         NaN
# 27        76939     NaN     NaN         NaN
# 28        76940  0.9644  0.9280      0.0493
# 29        76941     NaN     NaN         NaN
# 30        77861     NaN     NaN         NaN
# 31        77862 -0.0020 -0.0030     -0.0026
# 32        77863 -0.0019 -0.0023     -0.0007
# 33        77881  0.0200  0.0214      0.0229
# 34        77882  0.0073  0.0078      0.0196
# 35        77887  0.0129  0.0138      0.0169
# 36        77888  0.0067  0.0067      0.0123
# 37        77893  0.0212  0.0219      0.0265
# 38        77894  0.0132  0.0121      0.0263
# 39        77899  0.0396  0.0421      0.0271
# 40        77900  0.0402  0.0427      0.0270
# 41        77901  0.0430  0.0453      0.0289
# 42        77902  0.0409  0.0437      0.0269
# 43        77903  0.0410  0.0433      0.0249
# 44        77904  0.0403  0.0433      0.0267
# 45        77905  0.0412  0.0435      0.0265
# 46        77906  0.0383  0.0404      0.0259
# 47        77907  0.0386  0.0405      0.0283
# 48        77908  0.0481  0.0494      0.0309
# 49        77909  0.0404  0.0409      0.0249
# 50        77910  0.0413  0.0414      0.0245
# 51        77911  0.0091  0.0069      0.0139
# 52        77912  0.0003 -0.0021      0.0112
# 53        77913  0.0288  0.0308      0.0263
# 54        77914  0.0335  0.0346      0.0266
# 55        77927  0.0391  0.0417      0.0289
# 56        77928  0.0318  0.0335      0.0273
# 57        78122 -0.0040  0.0005     -0.0004
# 58        78159  0.0851  0.0814      0.0199
# 59        78160  0.1041  0.1000      0.0201
# 60        78161 -0.0015  0.0012     -0.0025
# 61        78162  0.4190  0.4641      0.0239
# 62        78163  0.7803  0.7747      0.0378
# 63        78164  0.4962  0.4592      0.0614
# 64        78165  0.7248  0.7024      0.0146
# 65        78166  0.6996  0.7996      0.0229
# 66        78167  0.6936  0.7514      0.0175
# 67        78168  0.3689  0.6023      0.0034
# 68        78169  0.2841  0.4045      0.0159
# 69        78170  0.8060  0.8206      0.0428
# 70        78187  0.0006  0.0047     -0.0022
# 71        78192  0.0008  0.0050     -0.0022
# 72        82270     NaN     NaN         NaN

# %%
corr_values_2 = corr_values_2.round(4)
corr_values_2.to_csv(main_path+'correlations_2.csv', index=False)

# %% [markdown]
# #### Junta em um só arquivo

# %%
corr_values_1 = pd.read_csv(main_path+'correlations.csv')
corr_values_full = pd.concat([corr_values_1,corr_values_2])

# %%
print(corr_values_full.shape)
corr_values_full['id_indicador'].nunique()
# Out:
# (280, 4)
# 280

# %%
corr_values_full.to_csv(main_path+'correlations_full.csv', index=False)

# %%
corr_values_full
# Out:
#     id_indicador  Mortes   Casos  Letalidade
# 0           5903  0.0332  0.0356      0.0259
# 1           5908  0.0404  0.0428      0.0270
# 2           5913  0.0434  0.0440      0.0270
# 3           5924  0.0244  0.0264      0.0252
# 4           5929  0.0319  0.0337      0.0268
# 5           5934  0.0328  0.0328      0.0286
# 6           5945  0.0282  0.0287      0.0300
# 7           5950  0.0399  0.0429      0.0301
# 8           5955  0.0299  0.0297      0.0287
# 9          15752 -0.0012 -0.0018     -0.0003
# 10         15754 -0.0025  0.0020      0.0008
# 11         15755 -0.0024  0.0014      0.0024
# 12         15756 -0.0018  0.0062     -0.0046
# 13         15760 -0.0012 -0.0018     -0.0003
# 14         15765 -0.0028  0.0003      0.0021
# 15         15769 -0.0021  0.0021     -0.0004
# 16         15773 -0.0022 -0.0001      0.0069
# 17         15777 -0.0025  0.0010      0.0032
# 18         15781 -0.0027  0.0009      0.0016
# 19         15785 -0.0019  0.0026      0.0054
# 20         15789 -0.0002  0.0050      0.0001
# 21         15793 -0.0022  0.0039     -0.0051
# 22         15797 -0.0025  0.0037      0.0004
# 23         15801 -0.0046 -0.0009      0.0074
# 24         15805 -0.0019  0.0023      0.0056
# 25         15809 -0.0017  0.0032      0.0084
# 26         15813 -0.0021  0.0033     -0.0044
# 27         15817  0.0003  0.0049      0.0092
# 28         15820 -0.0012 -0.0018     -0.0003
# 29         15824 -0.0028  0.0018     -0.0038
# 30         15829 -0.0024  0.0016      0.0002
# 31         15833 -0.0013  0.0014      0.0148
# 32         15837 -0.0015  0.0031     -0.0077
# 33         21636 -0.0021  0.0034     -0.0039
# 34         21637 -0.0021  0.0033     -0.0057
# 35         21638 -0.0008  0.0048     -0.0045
# 36         21639 -0.0020  0.0066     -0.0032
# 37         21640 -0.0010  0.0083     -0.0065
# 38         21641 -0.0009  0.0074     -0.0048
# 39         21642 -0.0024  0.0038     -0.0030
# 40         21643 -0.0026  0.0016     -0.0010
# 41         21644 -0.0027  0.0009      0.0026
# 42         21645 -0.0027  0.0006      0.0037
# 43         21646 -0.0027  0.0010      0.0024
# 44         21647 -0.0022  0.0017      0.0021
# 45         21906 -0.0020 -0.0029     -0.0157
# 46         21907 -0.0017 -0.0027     -0.0162
# 47         21910 -0.0008 -0.0024     -0.0161
# 48         21911 -0.0013 -0.0026     -0.0150
# 49         21912 -0.0017 -0.0028     -0.0166
# 50         21913 -0.0018 -0.0031     -0.0159
# 51         28120  0.9056  0.9152      0.0330
# 52         28122  0.9034  0.9027      0.0327
# 53         28123  0.8741  0.8930      0.0357
# 54         28124  0.7042  0.7661      0.0178
# 55         28125  0.8633  0.9156      0.0265
# 56         28126  0.8953  0.8873      0.0304
# 57         28127  0.9323  0.8740      0.0386
# 58         28128  0.8816  0.9116      0.0388
# 59         28129  0.7674  0.8266      0.0151
# 60         28130  0.9273  0.9342      0.0403
# 61         28131  0.7002  0.7691      0.0168
# 62         28132  0.8876  0.8968      0.0247
# 63         28133  0.6946  0.7533      0.0081
# 64         28135 -0.0026 -0.0032     -0.0011
# 65         28136 -0.0033 -0.0040     -0.0004
# 66         28137 -0.0032 -0.0038     -0.0004
# 67         28139 -0.0031 -0.0038     -0.0016
# 68         28140 -0.0035 -0.0042      0.0007
# 69         28141 -0.0035 -0.0044      0.0011
# 70         28142 -0.0013 -0.0018      0.0008
# 71         28143 -0.0042 -0.0046     -0.0006
# 72         28144 -0.0035 -0.0043      0.0014
# 73         28145 -0.0027 -0.0035     -0.0028
# 74         28147 -0.0027 -0.0036     -0.0024
# 75         28148 -0.0027 -0.0035     -0.0036
# 76         28149 -0.0025 -0.0036     -0.0006
# 77         28150 -0.0028 -0.0035     -0.0001
# 78         28151 -0.0035 -0.0061      0.0160
# 79         28152 -0.0045 -0.0062      0.0111
# 80         28154 -0.0041 -0.0049      0.0053
# 81         28155 -0.0006 -0.0021      0.0012
# 82         28157 -0.0047 -0.0046      0.0111
# 83         28158 -0.0039 -0.0054      0.0041
# 84         28159 -0.0028 -0.0037     -0.0023
# 85         28160 -0.0034 -0.0036      0.0231
# 86         28161 -0.0008 -0.0007     -0.0131
# 87         28162  0.0049  0.0038      0.0117
# 88         28163  0.0319  0.0338      0.0159
# 89         28164  0.0439  0.0429      0.0177
# 90         28166  0.0342  0.0328      0.0118
# 91         28167  0.0244  0.0267      0.0132
# 92         28168  0.0418  0.0417      0.0153
# 93         28169  0.0233  0.0271      0.0150
# 94         28170  0.0371  0.0350      0.0209
# 95         28171  0.0412  0.0387      0.0193
# 96         28172  0.0240  0.0268      0.0132
# 97         28173  0.0351  0.0341      0.0154
# 98         28174  0.0272  0.0263      0.0153
# 99         28231  0.0217  0.0239      0.0110
# 100        28232  0.0217  0.0240      0.0106
# 101        28233  0.0176  0.0180      0.0155
# 102        28234  0.0621  0.0625      0.0302
# 103        28235  0.0262  0.0351     -0.0043
# 104        28236  0.0540  0.0585      0.0030
# 105        28237  0.0567  0.0554      0.0336
# 106        28239  0.0214  0.0237      0.0103
# 107        28240  0.0254  0.0296      0.0136
# 108        28241  0.0227  0.0249      0.0099
# 109        28242  0.0564  0.0569      0.0245
# 110        28243  0.0580  0.0578      0.0255
# 111        28244  0.0282  0.0293      0.0126
# 112        28245  0.0632  0.0598      0.0181
# 113        28246  0.0512  0.0508      0.0194
# 114        28247  0.0454  0.0484      0.0153
# 115        28249  0.0396  0.0401      0.0170
# 116        28257  0.0319  0.0337      0.0142
# 117        28266  0.0325  0.0341      0.0144
# 118        28267  0.0151  0.0183      0.0076
# 119        28268  0.0443  0.0445      0.0204
# 120        28269  0.0245  0.0263      0.0120
# 121        28270  0.0319  0.0319      0.0172
# 122        28271  0.0267  0.0293      0.0191
# 123        28280  0.0198  0.0227      0.0182
# 124        28288  0.0261  0.0288      0.0156
# 125        28297  0.0193  0.0193      0.0155
# 126        28298  0.0184  0.0188      0.0127
# 127        28299  0.0190  0.0189      0.0188
# 128        28301  0.0167  0.0171      0.0135
# 129        28302  0.0197  0.0194      0.0156
# 130        28304  0.0201  0.0186      0.0147
# 131        28305  0.0220  0.0228      0.0143
# 132        28306  0.0258  0.0260      0.0110
# 133        28307  0.0181  0.0181      0.0101
# 134        28308  0.0180  0.0177      0.0100
# 135        28309  0.0159  0.0158      0.0097
# 136        28310  0.0202  0.0201      0.0131
# 137        28311  0.0265  0.0258      0.0162
# 138        28313  0.0359  0.0371      0.0138
# 139        28314  0.0206  0.0195      0.0129
# 140        28315  0.0435  0.0448      0.0125
# 141        28316  0.0140  0.0161      0.0093
# 142        28317  0.0186  0.0167      0.0171
# 143        28318  0.0198  0.0169      0.0169
# 144        29166  0.0315  0.0301      0.0157
# 145        29167  0.0057  0.0233     -0.0280
# 146        29168  0.0089  0.0036      0.0234
# 147        29169 -0.0176 -0.0344     -0.0060
# 148        29170     NaN     NaN         NaN
# 149        29171  0.0337  0.0329      0.0155
# 150        29748  0.0042  0.0083      0.0053
# 151        29749 -0.0033 -0.0040     -0.0005
# 152        29750  0.0042  0.0083      0.0053
# 153        29751  0.0042  0.0083      0.0053
# 154        29752  0.0042  0.0083      0.0053
# 155        29753  0.0042  0.0083      0.0053
# 156        29754  0.0042  0.0083      0.0053
# 157        29755  0.0042  0.0083      0.0053
# 158        29756  0.0320  0.0338      0.0158
# 159        30255  0.1109  0.1415     -0.0080
# 160        30279 -0.0055 -0.0057     -0.0328
# 161        46997  0.9348  0.9202      0.0346
# 162        46998  0.9341  0.9106      0.0352
# 163        46999  0.9250  0.9170      0.0344
# 164        47001  0.0680  0.0936     -0.0464
# 165        47002  0.0697  0.0977     -0.0256
# 166        47004  0.9286  0.9285      0.0340
# 167        47006  0.0483  0.1137     -0.0428
# 168        47007  0.8232  0.7920      0.0379
# 169        47008  0.9125  0.8910      0.0315
# 170        47009  0.7158  0.8310      0.0312
# 171        47010  0.9311  0.9167      0.0352
# 172        47012  0.0434  0.1060     -0.0429
# 173        47013  0.8435  0.7933      0.0428
# 174        47014  0.9146  0.8810      0.0314
# 175        47015  0.7365  0.8495      0.0318
# 176        47018  0.0461  0.1088     -0.0484
# 177        47019  0.7900  0.7794      0.0371
# 178        47020  0.9204  0.9270      0.0327
# 179        47022  0.9466  0.8659      0.0368
# 180        47023  0.9376  0.8746      0.0347
# 181        47024  0.9255  0.8673      0.0351
# 182        47374  0.0337  0.0347      0.0084
# 183        60409     NaN     NaN         NaN
# 184        76821     NaN     NaN         NaN
# 185        76822     NaN     NaN         NaN
# 186        76866     NaN     NaN         NaN
# 187        76867  0.0122  0.0158     -0.0142
# 188        76868  0.0168  0.0370     -0.0400
# 189        76869     NaN     NaN         NaN
# 190        76875  0.0320  0.0519     -0.0057
# 191        76877     NaN     NaN         NaN
# 192        76878     NaN     NaN         NaN
# 193        76879     NaN     NaN         NaN
# 194        76880     NaN     NaN         NaN
# 195        76881     NaN     NaN         NaN
# 196        76883     NaN     NaN         NaN
# 197        76884     NaN     NaN         NaN
# 198        76885     NaN     NaN         NaN
# 199        76886     NaN     NaN         NaN
# 200        76887     NaN     NaN         NaN
# 201        76890     NaN     NaN         NaN
# 202        76892     NaN     NaN         NaN
# 203        76894     NaN     NaN         NaN
# 204        76896     NaN     NaN         NaN
# 205        76899     NaN     NaN         NaN
# 206        76906     NaN     NaN         NaN
# 0          76838     NaN     NaN         NaN
# 1          76839     NaN     NaN         NaN
# 2          76906     NaN     NaN         NaN
# 3          76908     NaN     NaN         NaN
# 4          76910     NaN     NaN         NaN
# 5          76912     NaN     NaN         NaN
# 6          76915     NaN     NaN         NaN
# 7          76916     NaN     NaN         NaN
# 8          76918     NaN     NaN         NaN
# 9          76920     NaN     NaN         NaN
# 10         76921     NaN     NaN         NaN
# 11         76922     NaN     NaN         NaN
# 12         76923     NaN     NaN         NaN
# 13         76924     NaN     NaN         NaN
# 14         76925     NaN     NaN         NaN
# 15         76926     NaN     NaN         NaN
# 16         76927     NaN     NaN         NaN
# 17         76928     NaN     NaN         NaN
# 18         76929     NaN     NaN         NaN
# 19         76930     NaN     NaN         NaN
# 20         76931     NaN     NaN         NaN
# 21         76932     NaN     NaN         NaN
# 22         76933     NaN     NaN         NaN
# 23         76934     NaN     NaN         NaN
# 24         76936     NaN     NaN         NaN
# 25         76937 -0.0051 -0.0017     -0.0080
# 26         76938     NaN     NaN         NaN
# 27         76939     NaN     NaN         NaN
# 28         76940  0.9644  0.9280      0.0493
# 29         76941     NaN     NaN         NaN
# 30         77861     NaN     NaN         NaN
# 31         77862 -0.0020 -0.0030     -0.0026
# 32         77863 -0.0019 -0.0023     -0.0007
# 33         77881  0.0200  0.0214      0.0229
# 34         77882  0.0073  0.0078      0.0196
# 35         77887  0.0129  0.0138      0.0169
# 36         77888  0.0067  0.0067      0.0123
# 37         77893  0.0212  0.0219      0.0265
# 38         77894  0.0132  0.0121      0.0263
# 39         77899  0.0396  0.0421      0.0271
# 40         77900  0.0402  0.0427      0.0270
# 41         77901  0.0430  0.0453      0.0289
# 42         77902  0.0409  0.0437      0.0269
# 43         77903  0.0410  0.0433      0.0249
# 44         77904  0.0403  0.0433      0.0267
# 45         77905  0.0412  0.0435      0.0265
# 46         77906  0.0383  0.0404      0.0259
# 47         77907  0.0386  0.0405      0.0283
# 48         77908  0.0481  0.0494      0.0309
# 49         77909  0.0404  0.0409      0.0249
# 50         77910  0.0413  0.0414      0.0245
# 51         77911  0.0091  0.0069      0.0139
# 52         77912  0.0003 -0.0021      0.0112
# 53         77913  0.0288  0.0308      0.0263
# 54         77914  0.0335  0.0346      0.0266
# 55         77927  0.0391  0.0417      0.0289
# 56         77928  0.0318  0.0335      0.0273
# 57         78122 -0.0040  0.0005     -0.0004
# 58         78159  0.0851  0.0814      0.0199
# 59         78160  0.1041  0.1000      0.0201
# 60         78161 -0.0015  0.0012     -0.0025
# 61         78162  0.4190  0.4641      0.0239
# 62         78163  0.7803  0.7747      0.0378
# 63         78164  0.4962  0.4592      0.0614
# 64         78165  0.7248  0.7024      0.0146
# 65         78166  0.6996  0.7996      0.0229
# 66         78167  0.6936  0.7514      0.0175
# 67         78168  0.3689  0.6023      0.0034
# 68         78169  0.2841  0.4045      0.0159
# 69         78170  0.8060  0.8206      0.0428
# 70         78187  0.0006  0.0047     -0.0022
# 71         78192  0.0008  0.0050     -0.0022
# 72         82270     NaN     NaN         NaN
